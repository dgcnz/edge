# %% [markdown]
# # Testing Tensor of shapes

# %% [markdown]
# One of the things its bothering me is that `spatial_shapes` is a tensor of shapes that obtained from a list of "specialized" tensors (or at least that's the intention).
#
# To explain this a bit further, let's implement minimal reproducible example (MRE) to isolate the error from all the complicated code. We'll use `dynamo.explain` to debug our code.

# %%
import torch
import torch.nn as nn
import typing
import torch._dynamo as dynamo
import logging

# %%
def shapes_to_tensor(x: typing.List[int], device: typing.Optional[torch.device] = None) -> torch.Tensor:
    """
    Turn a list of integer scalars or integer Tensor scalars into a vector,
    in a way that's both traceable and scriptable.

    In tracing, `x` should be a list of scalar Tensor, so the output can trace to the inputs.
    In scripting or eager, `x` should be a list of int.
    """
    if torch.jit.is_scripting():
        return torch.as_tensor(x, device=device)
    if torch.jit.is_tracing() or torch._dynamo.is_compiling():
        # assert all(
        #     [isinstance(t, torch.Tensor) for t in x]
        # ), "Shape should be tensor during tracing!"
        # as_tensor should not be used in tracing because it records a constant
        ret = torch.stack(x)
        if ret.device != device:  # avoid recording a hard-coded device if not necessary
            ret = ret.to(device=device)
        return ret
    return torch.as_tensor(x, device=device)

# %%
from torch._dynamo.utils import get_fake_value

# %%
import numpy as np
class NetMRE(nn.Module):
    def __init__(self):
        super().__init__()
        self.ss: typing.Final[typing.List[typing.Tuple[int, int]]] =[(150, 100), (75, 50), (37, 25), (19, 13)]
    
    def forward(self, x: typing.List[torch.Tensor]):
        # Let's annotate possible culprits with C{N}
        # C2: tensor casting
        # C3: type overriding typing.List[typing.Tuple[int, int]] to torch.Tensor
        # spatial_shapes_tensor = torch.as_tensor(spatial_shapes, dtype=torch.long)
        reference_points = self.get_reference_points(torch.asarray(self.ss, copy=False))
        return reference_points
    
    @staticmethod
    def get_reference_points(
        spatial_shapes: torch.Tensor,
    ): 
        reference_points_list = []
        for H, W in spatial_shapes:
            lin = torch.linspace(0.5, H - 0.5, H, dtype=torch.float32) # --- breaks here
            reference_points_list.append(lin)
        return reference_points_list

# %%
import numpy as np
import array
class NetMRE(nn.Module):
    def forward(self, x: typing.List[torch.Tensor]):
        # Let's annotate possible culprits with C{N}
        spatial_shapes: typing.List[typing.Tuple[int, int]] = []
        for i, xi in enumerate(x):
            spatial_shapes.append(xi.shape[2:4])  # C1: tuple casting

        # C2: tensor casting
        # C3: type overriding typing.List[typing.Tuple[int, int]] to torch.Tensor
        spatial_shapes = array.array("i", spatial_shapes)
        spatial_shapes_tensor = torch.frombuffer(spatial_shapes)
        # spatial_shapes_tensor = torch.as_tensor(spatial_shapes, dtype=torch.long)
        reference_points = self.get_reference_points(spatial_shapes_tensor)
        return reference_points
    
    @staticmethod
    def get_reference_points(
        spatial_shapes: torch.Tensor,
    ): 
        reference_points_list = []
        for H, W in spatial_shapes:
            lin = torch.linspace(0.5, H - 0.5, H, dtype=torch.float32) # --- breaks here
            reference_points_list.append(lin)
        return reference_points_list

# %%
# sst = [(150, 100), (75, 50), (37, 25), (19, 13)]
example_kwargs = {
    "x": [
        # torch.rand(1, 3, 64, 64),
        # torch.rand(1, 3, 32, 32),
        torch.rand(1, 3, 150, 100),
        torch.rand(1, 3, 75, 50),
        torch.rand(1, 3, 37, 25),
        torch.rand(1, 3, 19, 13),
    ],
}

# %%
exported_program: torch.export.ExportedProgram = torch.export.export(
    NetMRE(), (), kwargs=example_kwargs, strict=True,
)
print(exported_program)
# Out:
# V0904 22:04:10.005000 440 torch/_dynamo/convert_frame.py:855] [9/0] torchdynamo start compiling forward /var/folders/rk/fqb5s6dn6sl66ntxp1ssybz80000gn/T/ipykernel_440/1310961134.py:4, stack (elided 4 frames):
# V0904 22:04:10.005000 440 torch/_dynamo/convert_frame.py:855] [9/0]   File "/Users/dgcnz/.pyenv/versions/3.10.12/lib/python3.10/runpy.py", line 196, in _run_module_as_main
# V0904 22:04:10.005000 440 torch/_dynamo/convert_frame.py:855] [9/0]     return _run_code(code, main_globals, None,
# V0904 22:04:10.005000 440 torch/_dynamo/convert_frame.py:855] [9/0]   File "/Users/dgcnz/.pyenv/versions/3.10.12/lib/python3.10/runpy.py", line 86, in _run_code
# V0904 22:04:10.005000 440 torch/_dynamo/convert_frame.py:855] [9/0]     exec(code, run_globals)
# V0904 22:04:10.005000 440 torch/_dynamo/convert_frame.py:855] [9/0]   File "/Users/dgcnz/development/amsterdam/edge/.venv/lib/python3.10/site-packages/ipykernel_launcher.py", line 18, in <module>
# V0904 22:04:10.005000 440 torch/_dynamo/convert_frame.py:855] [9/0]     app.launch_new_instance()
# V0904 22:04:10.005000 440 torch/_dynamo/convert_frame.py:855] [9/0]   File "/Users/dgcnz/development/amsterdam/edge/.venv/lib/python3.10/site-packages/traitlets/config/application.py", line 1075, in launch_instance
# V0904 22:04:10.005000 440 torch/_dynamo/convert_frame.py:855] [9/0]     app.start()
# V0904 22:04:10.005000 440 torch/_dynamo/convert_frame.py:855] [9/0]   File "/Users/dgcnz/development/amsterdam/edge/.venv/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 739, in start
# V0904 22:04:10.005000 440 torch/_dynamo/convert_frame.py:855] [9/0]     self.io_loop.start()
# V0904 22:04:10.005000 440 torch/_dynamo/convert_frame.py:855] [9/0]   File "/Users/dgcnz/development/amsterdam/edge/.venv/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 205, in start
# V0904 22:04:10.005000 440 torch/_dynamo/convert_frame.py:855] [9/0]     self.asyncio_loop.run_forever()
# V0904 22:04:10.005000 440 torch/_dynamo/convert_frame.py:855] [9/0]   File "/Users/dgcnz/.pyenv/versions/3.10.12/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
# V0904 22:04:10.005000 440 torch/_dynamo/convert_frame.py:855] [9/0]     self._run_once()
# V0904 22:04:10.005000 440 torch/_dynamo/convert_frame.py:855] [9/0]   File "/Users/dgcnz/.pyenv/versions/3.10.12/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
# V0904 22:04:10.005000 440 torch/_dynamo/convert_frame.py:855] [9/0]     handle._run()
# V0904 22:04:10.005000 440 torch/_dynamo/convert_frame.py:855] [9/0]   File "/Users/dgcnz/.pyenv/versions/3.10.12/lib/python3.10/asyncio/events.py", line 80, in _run
# V0904 22:04:10.005000 440 torch/_dynamo/convert_frame.py:855] [9/0]     self._context.run(self._callback, *self._args)
# V0904 22:04:10.005000 440 torch/_dynamo/convert_frame.py:855] [9/0]   File "/Users/dgcnz/development/amsterdam/edge/.venv/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
# V0904 22:04:10.005000 440 torch/_dynamo/convert_frame.py:855] [9/0]     await self.process_one()
# V0904 22:04:10.005000 440 torch/_dynamo/convert_frame.py:855] [9/0]   File "/Users/dgcnz/development/amsterdam/edge/.venv/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 534, in process_one
# V0904 22:04:10.005000 440 torch/_dynamo/convert_frame.py:855] [9/0]     await dispatch(*args)
# V0904 22:04:10.005000 440 torch/_dynamo/convert_frame.py:855] [9/0]   File "/Users/dgcnz/development/amsterdam/edge/.venv/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
# V0904 22:04:10.005000 440 torch/_dynamo/convert_frame.py:855] [9/0]     await result
# V0904 22:04:10.005000 440 torch/_dynamo/convert_frame.py:855] [9/0]   File "/Users/dgcnz/development/amsterdam/edge/.venv/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
# V0904 22:04:10.005000 440 torch/_dynamo/convert_frame.py:855] [9/0]     await super().execute_request(stream, ident, parent)
# V0904 22:04:10.005000 440 torch/_dynamo/convert_frame.py:855] [9/0]   File "/Users/dgcnz/development/amsterdam/edge/.venv/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
# V0904 22:04:10.005000 440 torch/_dynamo/convert_frame.py:855] [9/0]     reply_content = await reply_content
# V0904 22:04:10.005000 440 torch/_dynamo/convert_frame.py:855] [9/0]   File "/Users/dgcnz/development/amsterdam/edge/.venv/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
# V0904 22:04:10.005000 440 torch/_dynamo/convert_frame.py:855] [9/0]     res = shell.run_cell(
# V0904 22:04:10.005000 440 torch/_dynamo/convert_frame.py:855] [9/0]   File "/Users/dgcnz/development/amsterdam/edge/.venv/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
# V0904 22:04:10.005000 440 torch/_dynamo/convert_frame.py:855] [9/0]     return super().run_cell(*args, **kwargs)
# V0904 22:04:10.005000 440 torch/_dynamo/convert_frame.py:855] [9/0]   File "/Users/dgcnz/development/amsterdam/edge/.venv/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3048, in run_cell
# V0904 22:04:10.005000 440 torch/_dynamo/convert_frame.py:855] [9/0]     result = self._run_cell(
# V0904 22:04:10.005000 440 torch/_dynamo/convert_frame.py:855] [9/0]   File "/Users/dgcnz/development/amsterdam/edge/.venv/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3103, in _run_cell
# V0904 22:04:10.005000 440 torch/_dynamo/convert_frame.py:855] [9/0]     result = runner(coro)
# V0904 22:04:10.005000 440 torch/_dynamo/convert_frame.py:855] [9/0]   File "/Users/dgcnz/development/amsterdam/edge/.venv/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
# V0904 22:04:10.005000 440 torch/_dynamo/convert_frame.py:855] [9/0]     coro.send(None)
# V0904 22:04:10.005000 440 torch/_dynamo/convert_frame.py:855] [9/0]   File "/Users/dgcnz/development/amsterdam/edge/.venv/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3308, in run_cell_async
# V0904 22:04:10.005000 440 torch/_dynamo/convert_frame.py:855] [9/0]     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# V0904 22:04:10.005000 440 torch/_dynamo/convert_frame.py:855] [9/0]   File "/Users/dgcnz/development/amsterdam/edge/.venv/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3490, in run_ast_nodes
# V0904 22:04:10.005000 440 torch/_dynamo/convert_frame.py:855] [9/0]     if await self.run_code(code, result, async_=asy):
# V0904 22:04:10.005000 440 torch/_dynamo/convert_frame.py:855] [9/0]   File "/Users/dgcnz/development/amsterdam/edge/.venv/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3550, in run_code
# V0904 22:04:10.005000 440 torch/_dynamo/convert_frame.py:855] [9/0]     exec(code_obj, self.user_global_ns, self.user_ns)
# V0904 22:04:10.005000 440 torch/_dynamo/convert_frame.py:855] [9/0]   File "/var/folders/rk/fqb5s6dn6sl66ntxp1ssybz80000gn/T/ipykernel_440/4187046903.py", line 1, in <module>
# V0904 22:04:10.005000 440 torch/_dynamo/convert_frame.py:855] [9/0]     exported_program: torch.export.ExportedProgram = torch.export.export(
# V0904 22:04:10.005000 440 torch/_dynamo/convert_frame.py:855] [9/0]   File "/Users/dgcnz/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/export/__init__.py", line 258, in export
# V0904 22:04:10.005000 440 torch/_dynamo/convert_frame.py:855] [9/0]     return _export(
# V0904 22:04:10.005000 440 torch/_dynamo/convert_frame.py:855] [9/0]   File "/Users/dgcnz/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/export/_trace.py", line 980, in wrapper
# V0904 22:04:10.005000 440 torch/_dynamo/convert_frame.py:855] [9/0]     ep = fn(*args, **kwargs)
# V0904 22:04:10.005000 440 torch/_dynamo/convert_frame.py:855] [9/0]   File "/Users/dgcnz/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/export/exported_program.py", line 105, in wrapper
# V0904 22:04:10.005000 440 torch/_dynamo/convert_frame.py:855] [9/0]     return fn(*args, **kwargs)
# V0904 22:04:10.005000 440 torch/_dynamo/convert_frame.py:855] [9/0]   File "/Users/dgcnz/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/export/_trace.py", line 1915, in _export
# V0904 22:04:10.005000 440 torch/_dynamo/convert_frame.py:855] [9/0]     export_artifact = export_func(  # type: ignore[operator]
# V0904 22:04:10.005000 440 torch/_dynamo/convert_frame.py:855] [9/0]   File "/Users/dgcnz/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/export/_trace.py", line 1214, in _strict_export
# V0904 22:04:10.005000 440 torch/_dynamo/convert_frame.py:855] [9/0]     return _strict_export_lower_to_aten_ir(
# V0904 22:04:10.005000 440 torch/_dynamo/convert_frame.py:855] [9/0]   File "/Users/dgcnz/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/export/_trace.py", line 1242, in _strict_export_lower_to_aten_ir
# V0904 22:04:10.005000 440 torch/_dynamo/convert_frame.py:855] [9/0]     gm_torch_level = _export_to_torch_ir(
# V0904 22:04:10.005000 440 torch/_dynamo/convert_frame.py:855] [9/0]   File "/Users/dgcnz/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/export/_trace.py", line 550, in _export_to_torch_ir
# V0904 22:04:10.005000 440 torch/_dynamo/convert_frame.py:855] [9/0]     gm_torch_level, _ = torch._dynamo.export(
# V0904 22:04:10.005000 440 torch/_dynamo/convert_frame.py:855] [9/0]   File "/Users/dgcnz/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/_dynamo/eval_frame.py", line 1432, in inner
# V0904 22:04:10.005000 440 torch/_dynamo/convert_frame.py:855] [9/0]     result_traced = opt_f(*args, **kwargs)
# V0904 22:04:10.005000 440 torch/_dynamo/convert_frame.py:855] [9/0]   File "/Users/dgcnz/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1736, in _wrapped_call_impl
# V0904 22:04:10.005000 440 torch/_dynamo/convert_frame.py:855] [9/0]     return self._call_impl(*args, **kwargs)
# V0904 22:04:10.005000 440 torch/_dynamo/convert_frame.py:855] [9/0]   File "/Users/dgcnz/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1747, in _call_impl
# V0904 22:04:10.005000 440 torch/_dynamo/convert_frame.py:855] [9/0]     return forward_call(*args, **kwargs)
# V0904 22:04:10.005000 440 torch/_dynamo/convert_frame.py:855] [9/0]   File "/Users/dgcnz/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/_dynamo/eval_frame.py", line 465, in _fn
# V0904 22:04:10.005000 440 torch/_dynamo/convert_frame.py:855] [9/0]     return fn(*args, **kwargs)
# V0904 22:04:10.005000 440 torch/_dynamo/convert_frame.py:855] [9/0]   File "/Users/dgcnz/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1736, in _wrapped_call_impl
# V0904 22:04:10.005000 440 torch/_dynamo/convert_frame.py:855] [9/0]     return self._call_impl(*args, **kwargs)
# V0904 22:04:10.005000 440 torch/_dynamo/convert_frame.py:855] [9/0]
# I0904 22:04:10.009000 440 torch/_dynamo/logging.py:57] [9/0] Step 1: torchdynamo start tracing forward /var/folders/rk/fqb5s6dn6sl66ntxp1ssybz80000gn/T/ipykernel_440/1310961134.py:4
# V0904 22:04:10.010000 440 torch/fx/experimental/symbolic_shapes.py:2500] [9/0] create_env
# V0904 22:04:10.015000 440 torch/_dynamo/output_graph.py:2076] [9/0] create_graph_input L_x_0_ L['x'][0]
# V0904 22:04:10.017000 440 torch/_dynamo/variables/builder.py:2690] [9/0] wrap_to_fake L['x'][0] (1, 3, 150, 100) StatefulSymbolicContext(dynamic_sizes=[<DimDynamic.DYNAMIC: 0>, <DimDynamic.DYNAMIC: 0>, <DimDynamic.DYNAMIC: 0>, <DimDynamic.DYNAMIC: 0>], dynamic_strides=[<DimDynamic.INFER_STRIDE: 4>, <DimDynamic.INFER_STRIDE: 4>, <DimDynamic.INFER_STRIDE: 4>, <DimDynamic.INFER_STRIDE: 4>], constraint_sizes=[StrictMinMaxConstraint(warn_only=False, vr=VR[1, 1]), StrictMinMaxConstraint(warn_only=False, vr=VR[3, 3]), StrictMinMaxConstraint(warn_only=False, vr=VR[150, 150]), StrictMinMaxConstraint(warn_only=False, vr=VR[100, 100])], constraint_strides=[None, None, None, None], view_base_context=None, tensor_source=GetItemSource(base=LocalSource(local_name='x', cell_or_freevar=False), index=0, index_is_slice=False), shape_env_to_source_to_symbol_cache={}) <class 'torch.Tensor'>
# V0904 22:04:10.023000 440 torch/_dynamo/output_graph.py:2076] [9/0] create_graph_input L_x_1_ L['x'][1]
# V0904 22:04:10.025000 440 torch/_dynamo/variables/builder.py:2690] [9/0] wrap_to_fake L['x'][1] (1, 3, 75, 50) StatefulSymbolicContext(dynamic_sizes=[<DimDynamic.DYNAMIC: 0>, <DimDynamic.DYNAMIC: 0>, <DimDynamic.DYNAMIC: 0>, <DimDynamic.DYNAMIC: 0>], dynamic_strides=[<DimDynamic.INFER_STRIDE: 4>, <DimDynamic.INFER_STRIDE: 4>, <DimDynamic.INFER_STRIDE: 4>, <DimDynamic.INFER_STRIDE: 4>], constraint_sizes=[StrictMinMaxConstraint(warn_only=False, vr=VR[1, 1]), StrictMinMaxConstraint(warn_only=False, vr=VR[3, 3]), StrictMinMaxConstraint(warn_only=False, vr=VR[75, 75]), StrictMinMaxConstraint(warn_only=False, vr=VR[50, 50])], constraint_strides=[None, None, None, None], view_base_context=None, tensor_source=GetItemSource(base=LocalSource(local_name='x', cell_or_freevar=False), index=1, index_is_slice=False), shape_env_to_source_to_symbol_cache={}) <class 'torch.Tensor'>
# V0904 22:04:10.030000 440 torch/_dynamo/output_graph.py:2076] [9/0] create_graph_input L_x_2_ L['x'][2]
# V0904 22:04:10.032000 440 torch/_dynamo/variables/builder.py:2690] [9/0] wrap_to_fake L['x'][2] (1, 3, 37, 25) StatefulSymbolicContext(dynamic_sizes=[<DimDynamic.DYNAMIC: 0>, <DimDynamic.DYNAMIC: 0>, <DimDynamic.DYNAMIC: 0>, <DimDynamic.DYNAMIC: 0>], dynamic_strides=[<DimDynamic.INFER_STRIDE: 4>, <DimDynamic.INFER_STRIDE: 4>, <DimDynamic.INFER_STRIDE: 4>, <DimDynamic.INFER_STRIDE: 4>], constraint_sizes=[StrictMinMaxConstraint(warn_only=False, vr=VR[1, 1]), StrictMinMaxConstraint(warn_only=False, vr=VR[3, 3]), StrictMinMaxConstraint(warn_only=False, vr=VR[37, 37]), StrictMinMaxConstraint(warn_only=False, vr=VR[25, 25])], constraint_strides=[None, None, None, None], view_base_context=None, tensor_source=GetItemSource(base=LocalSource(local_name='x', cell_or_freevar=False), index=2, index_is_slice=False), shape_env_to_source_to_symbol_cache={}) <class 'torch.Tensor'>
# V0904 22:04:10.034000 440 torch/_dynamo/output_graph.py:2076] [9/0] create_graph_input L_x_3_ L['x'][3]
# V0904 22:04:10.035000 440 torch/_dynamo/variables/builder.py:2690] [9/0] wrap_to_fake L['x'][3] (1, 3, 19, 13) StatefulSymbolicContext(dynamic_sizes=[<DimDynamic.DYNAMIC: 0>, <DimDynamic.DYNAMIC: 0>, <DimDynamic.DYNAMIC: 0>, <DimDynamic.DYNAMIC: 0>], dynamic_strides=[<DimDynamic.INFER_STRIDE: 4>, <DimDynamic.INFER_STRIDE: 4>, <DimDynamic.INFER_STRIDE: 4>, <DimDynamic.INFER_STRIDE: 4>], constraint_sizes=[StrictMinMaxConstraint(warn_only=False, vr=VR[1, 1]), StrictMinMaxConstraint(warn_only=False, vr=VR[3, 3]), StrictMinMaxConstraint(warn_only=False, vr=VR[19, 19]), StrictMinMaxConstraint(warn_only=False, vr=VR[13, 13])], constraint_strides=[None, None, None, None], view_base_context=None, tensor_source=GetItemSource(base=LocalSource(local_name='x', cell_or_freevar=False), index=3, index_is_slice=False), shape_env_to_source_to_symbol_cache={}) <class 'torch.Tensor'>
# V0904 22:04:10.038000 440 torch/_dynamo/symbolic_convert.py:865] [9/0] [__trace_source] TRACE starts_line /var/folders/rk/fqb5s6dn6sl66ntxp1ssybz80000gn/T/ipykernel_440/1310961134.py:6 in forward
# V0904 22:04:10.038000 440 torch/_dynamo/symbolic_convert.py:865] [9/0] [__trace_source]             spatial_shapes: typing.List[typing.Tuple[int, int]] = []
# V0904 22:04:10.039000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE BUILD_LIST 0 []
# V0904 22:04:10.039000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE STORE_FAST spatial_shapes [ListVariable(length=0)]
# V0904 22:04:10.040000 440 torch/_dynamo/symbolic_convert.py:865] [9/0] [__trace_source] TRACE starts_line /var/folders/rk/fqb5s6dn6sl66ntxp1ssybz80000gn/T/ipykernel_440/1310961134.py:7 in forward
# V0904 22:04:10.040000 440 torch/_dynamo/symbolic_convert.py:865] [9/0] [__trace_source]             for i, xi in enumerate(x):
# V0904 22:04:10.040000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE LOAD_GLOBAL enumerate []
# V0904 22:04:10.042000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE LOAD_FAST x [PolyfilledFunctionVariable()]
# V0904 22:04:10.042000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE CALL_FUNCTION 1 [PolyfilledFunctionVariable(), ListVariable(length=4)]
# V0904 22:04:10.045000 440 torch/_dynamo/symbolic_convert.py:3099] [9/0] INLINING <code object enumerate at 0x146781420, file "/Users/dgcnz/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/_dynamo/polyfills/builtins.py", line 39>, inlined according trace_rules.lookup MOD_INLINELIST
# V0904 22:04:10.047000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE GEN_START 0 [BuiltinVariable()]
# V0904 22:04:10.047000 440 torch/_dynamo/symbolic_convert.py:865] [9/0] [__trace_source] TRACE starts_line /Users/dgcnz/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/_dynamo/polyfills/builtins.py:41 in enumerate (enumerate) (inline depth: 1)
# V0904 22:04:10.047000 440 torch/_dynamo/symbolic_convert.py:865] [9/0] [__trace_source]         if not isinstance(start, int):
# V0904 22:04:10.048000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE LOAD_GLOBAL isinstance []
# V0904 22:04:10.052000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE LOAD_FAST start [BuiltinVariable()]
# V0904 22:04:10.053000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE LOAD_GLOBAL int [BuiltinVariable(), ConstantVariable()]
# V0904 22:04:10.055000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE CALL_FUNCTION 2 [BuiltinVariable(), ConstantVariable(), BuiltinVariable()]
# V0904 22:04:10.057000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE POP_JUMP_IF_TRUE 32 [ConstantVariable()]
# V0904 22:04:10.058000 440 torch/_dynamo/symbolic_convert.py:865] [9/0] [__trace_source] TRACE starts_line /Users/dgcnz/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/_dynamo/polyfills/builtins.py:46 in enumerate (enumerate) (inline depth: 1)
# V0904 22:04:10.058000 440 torch/_dynamo/symbolic_convert.py:865] [9/0] [__trace_source]         for x in iterable:
# V0904 22:04:10.059000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE LOAD_FAST iterable []
# V0904 22:04:10.060000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE GET_ITER None [ListVariable(length=4)]
# V0904 22:04:10.061000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE FOR_ITER 60 [ListIteratorVariable(length=4, index=0)]
# V0904 22:04:10.062000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE STORE_FAST x [ListIteratorVariable(length=4, index=1), TensorVariable()]
# V0904 22:04:10.064000 440 torch/_dynamo/symbolic_convert.py:865] [9/0] [__trace_source] TRACE starts_line /Users/dgcnz/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/_dynamo/polyfills/builtins.py:47 in enumerate (enumerate) (inline depth: 1)
# V0904 22:04:10.064000 440 torch/_dynamo/symbolic_convert.py:865] [9/0] [__trace_source]             yield start, x
# V0904 22:04:10.065000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE LOAD_FAST start [ListIteratorVariable(length=4, index=1)]
# V0904 22:04:10.065000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE LOAD_FAST x [ListIteratorVariable(length=4, index=1), ConstantVariable()]
# V0904 22:04:10.066000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE BUILD_TUPLE 2 [ListIteratorVariable(length=4, index=1), ConstantVariable(), TensorVariable()]
# V0904 22:04:10.068000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE YIELD_VALUE None [ListIteratorVariable(length=4, index=1), TupleVariable(length=2)]
# V0904 22:04:10.069000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE POP_TOP None [ListIteratorVariable(length=4, index=1), ConstantVariable()]
# V0904 22:04:10.069000 440 torch/_dynamo/symbolic_convert.py:865] [9/0] [__trace_source] TRACE starts_line /Users/dgcnz/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/_dynamo/polyfills/builtins.py:48 in enumerate (enumerate) (inline depth: 1)
# V0904 22:04:10.069000 440 torch/_dynamo/symbolic_convert.py:865] [9/0] [__trace_source]             start += 1
# V0904 22:04:10.070000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE LOAD_FAST start [ListIteratorVariable(length=4, index=1)]
# V0904 22:04:10.071000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE LOAD_CONST 1 [ListIteratorVariable(length=4, index=1), ConstantVariable()]
# V0904 22:04:10.071000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE INPLACE_ADD None [ListIteratorVariable(length=4, index=1), ConstantVariable(), ConstantVariable()]
# V0904 22:04:10.072000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE STORE_FAST start [ListIteratorVariable(length=4, index=1), ConstantVariable()]
# V0904 22:04:10.072000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE JUMP_ABSOLUTE 36 [ListIteratorVariable(length=4, index=1)]
# V0904 22:04:10.073000 440 torch/_dynamo/symbolic_convert.py:865] [9/0] [__trace_source] TRACE starts_line /Users/dgcnz/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/_dynamo/polyfills/builtins.py:46 in enumerate (enumerate) (inline depth: 1)
# V0904 22:04:10.073000 440 torch/_dynamo/symbolic_convert.py:865] [9/0] [__trace_source]         for x in iterable:
# V0904 22:04:10.073000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE FOR_ITER 60 [ListIteratorVariable(length=4, index=1)]
# V0904 22:04:10.074000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE STORE_FAST x [ListIteratorVariable(length=4, index=2), TensorVariable()]
# V0904 22:04:10.075000 440 torch/_dynamo/symbolic_convert.py:865] [9/0] [__trace_source] TRACE starts_line /Users/dgcnz/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/_dynamo/polyfills/builtins.py:47 in enumerate (enumerate) (inline depth: 1)
# V0904 22:04:10.075000 440 torch/_dynamo/symbolic_convert.py:865] [9/0] [__trace_source]             yield start, x
# V0904 22:04:10.075000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE LOAD_FAST start [ListIteratorVariable(length=4, index=2)]
# V0904 22:04:10.076000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE LOAD_FAST x [ListIteratorVariable(length=4, index=2), ConstantVariable()]
# V0904 22:04:10.077000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE BUILD_TUPLE 2 [ListIteratorVariable(length=4, index=2), ConstantVariable(), TensorVariable()]
# V0904 22:04:10.077000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE YIELD_VALUE None [ListIteratorVariable(length=4, index=2), TupleVariable(length=2)]
# V0904 22:04:10.078000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE POP_TOP None [ListIteratorVariable(length=4, index=2), ConstantVariable()]
# V0904 22:04:10.078000 440 torch/_dynamo/symbolic_convert.py:865] [9/0] [__trace_source] TRACE starts_line /Users/dgcnz/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/_dynamo/polyfills/builtins.py:48 in enumerate (enumerate) (inline depth: 1)
# V0904 22:04:10.078000 440 torch/_dynamo/symbolic_convert.py:865] [9/0] [__trace_source]             start += 1
# V0904 22:04:10.079000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE LOAD_FAST start [ListIteratorVariable(length=4, index=2)]
# V0904 22:04:10.080000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE LOAD_CONST 1 [ListIteratorVariable(length=4, index=2), ConstantVariable()]
# V0904 22:04:10.080000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE INPLACE_ADD None [ListIteratorVariable(length=4, index=2), ConstantVariable(), ConstantVariable()]
# V0904 22:04:10.081000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE STORE_FAST start [ListIteratorVariable(length=4, index=2), ConstantVariable()]
# V0904 22:04:10.082000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE JUMP_ABSOLUTE 36 [ListIteratorVariable(length=4, index=2)]
# V0904 22:04:10.082000 440 torch/_dynamo/symbolic_convert.py:865] [9/0] [__trace_source] TRACE starts_line /Users/dgcnz/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/_dynamo/polyfills/builtins.py:46 in enumerate (enumerate) (inline depth: 1)
# V0904 22:04:10.082000 440 torch/_dynamo/symbolic_convert.py:865] [9/0] [__trace_source]         for x in iterable:
# V0904 22:04:10.083000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE FOR_ITER 60 [ListIteratorVariable(length=4, index=2)]
# V0904 22:04:10.083000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE STORE_FAST x [ListIteratorVariable(length=4, index=3), TensorVariable()]
# V0904 22:04:10.084000 440 torch/_dynamo/symbolic_convert.py:865] [9/0] [__trace_source] TRACE starts_line /Users/dgcnz/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/_dynamo/polyfills/builtins.py:47 in enumerate (enumerate) (inline depth: 1)
# V0904 22:04:10.084000 440 torch/_dynamo/symbolic_convert.py:865] [9/0] [__trace_source]             yield start, x
# V0904 22:04:10.085000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE LOAD_FAST start [ListIteratorVariable(length=4, index=3)]
# V0904 22:04:10.085000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE LOAD_FAST x [ListIteratorVariable(length=4, index=3), ConstantVariable()]
# V0904 22:04:10.086000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE BUILD_TUPLE 2 [ListIteratorVariable(length=4, index=3), ConstantVariable(), TensorVariable()]
# V0904 22:04:10.086000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE YIELD_VALUE None [ListIteratorVariable(length=4, index=3), TupleVariable(length=2)]
# V0904 22:04:10.087000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE POP_TOP None [ListIteratorVariable(length=4, index=3), ConstantVariable()]
# V0904 22:04:10.087000 440 torch/_dynamo/symbolic_convert.py:865] [9/0] [__trace_source] TRACE starts_line /Users/dgcnz/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/_dynamo/polyfills/builtins.py:48 in enumerate (enumerate) (inline depth: 1)
# V0904 22:04:10.087000 440 torch/_dynamo/symbolic_convert.py:865] [9/0] [__trace_source]             start += 1
# V0904 22:04:10.088000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE LOAD_FAST start [ListIteratorVariable(length=4, index=3)]
# V0904 22:04:10.089000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE LOAD_CONST 1 [ListIteratorVariable(length=4, index=3), ConstantVariable()]
# V0904 22:04:10.090000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE INPLACE_ADD None [ListIteratorVariable(length=4, index=3), ConstantVariable(), ConstantVariable()]
# V0904 22:04:10.090000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE STORE_FAST start [ListIteratorVariable(length=4, index=3), ConstantVariable()]
# V0904 22:04:10.091000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE JUMP_ABSOLUTE 36 [ListIteratorVariable(length=4, index=3)]
# V0904 22:04:10.091000 440 torch/_dynamo/symbolic_convert.py:865] [9/0] [__trace_source] TRACE starts_line /Users/dgcnz/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/_dynamo/polyfills/builtins.py:46 in enumerate (enumerate) (inline depth: 1)
# V0904 22:04:10.091000 440 torch/_dynamo/symbolic_convert.py:865] [9/0] [__trace_source]         for x in iterable:
# V0904 22:04:10.092000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE FOR_ITER 60 [ListIteratorVariable(length=4, index=3)]
# V0904 22:04:10.092000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE STORE_FAST x [ListIteratorVariable(length=4, index=4), TensorVariable()]
# V0904 22:04:10.093000 440 torch/_dynamo/symbolic_convert.py:865] [9/0] [__trace_source] TRACE starts_line /Users/dgcnz/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/_dynamo/polyfills/builtins.py:47 in enumerate (enumerate) (inline depth: 1)
# V0904 22:04:10.093000 440 torch/_dynamo/symbolic_convert.py:865] [9/0] [__trace_source]             yield start, x
# V0904 22:04:10.094000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE LOAD_FAST start [ListIteratorVariable(length=4, index=4)]
# V0904 22:04:10.094000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE LOAD_FAST x [ListIteratorVariable(length=4, index=4), ConstantVariable()]
# V0904 22:04:10.094000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE BUILD_TUPLE 2 [ListIteratorVariable(length=4, index=4), ConstantVariable(), TensorVariable()]
# V0904 22:04:10.095000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE YIELD_VALUE None [ListIteratorVariable(length=4, index=4), TupleVariable(length=2)]
# V0904 22:04:10.096000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE POP_TOP None [ListIteratorVariable(length=4, index=4), ConstantVariable()]
# V0904 22:04:10.097000 440 torch/_dynamo/symbolic_convert.py:865] [9/0] [__trace_source] TRACE starts_line /Users/dgcnz/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/_dynamo/polyfills/builtins.py:48 in enumerate (enumerate) (inline depth: 1)
# V0904 22:04:10.097000 440 torch/_dynamo/symbolic_convert.py:865] [9/0] [__trace_source]             start += 1
# V0904 22:04:10.097000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE LOAD_FAST start [ListIteratorVariable(length=4, index=4)]
# V0904 22:04:10.098000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE LOAD_CONST 1 [ListIteratorVariable(length=4, index=4), ConstantVariable()]
# V0904 22:04:10.098000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE INPLACE_ADD None [ListIteratorVariable(length=4, index=4), ConstantVariable(), ConstantVariable()]
# V0904 22:04:10.099000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE STORE_FAST start [ListIteratorVariable(length=4, index=4), ConstantVariable()]
# V0904 22:04:10.099000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE JUMP_ABSOLUTE 36 [ListIteratorVariable(length=4, index=4)]
# V0904 22:04:10.100000 440 torch/_dynamo/symbolic_convert.py:865] [9/0] [__trace_source] TRACE starts_line /Users/dgcnz/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/_dynamo/polyfills/builtins.py:46 in enumerate (enumerate) (inline depth: 1)
# V0904 22:04:10.100000 440 torch/_dynamo/symbolic_convert.py:865] [9/0] [__trace_source]         for x in iterable:
# V0904 22:04:10.100000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE FOR_ITER 60 [ListIteratorVariable(length=4, index=4)]
# V0904 22:04:10.101000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE LOAD_CONST None []
# V0904 22:04:10.102000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE RETURN_VALUE None [ConstantVariable()]
# V0904 22:04:10.102000 440 torch/_dynamo/symbolic_convert.py:3164] [9/0] DONE INLINING <code object enumerate at 0x146781420, file "/Users/dgcnz/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/_dynamo/polyfills/builtins.py", line 39>
# V0904 22:04:10.103000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE GET_ITER None [ListIteratorVariable(length=4, index=0)]
# V0904 22:04:10.103000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE FOR_ITER 42 [ListIteratorVariable(length=4, index=0)]
# V0904 22:04:10.104000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE UNPACK_SEQUENCE 2 [ListIteratorVariable(length=4, index=1), TupleVariable(length=2)]
# V0904 22:04:10.105000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE STORE_FAST i [ListIteratorVariable(length=4, index=1), TensorVariable(), ConstantVariable()]
# V0904 22:04:10.105000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE STORE_FAST xi [ListIteratorVariable(length=4, index=1), TensorVariable()]
# V0904 22:04:10.105000 440 torch/_dynamo/symbolic_convert.py:865] [9/0] [__trace_source] TRACE starts_line /var/folders/rk/fqb5s6dn6sl66ntxp1ssybz80000gn/T/ipykernel_440/1310961134.py:8 in forward
# V0904 22:04:10.105000 440 torch/_dynamo/symbolic_convert.py:865] [9/0] [__trace_source]                 spatial_shapes.append(xi.shape[2:4])  # C1: tuple casting
# V0904 22:04:10.106000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE LOAD_FAST spatial_shapes [ListIteratorVariable(length=4, index=1)]
# V0904 22:04:10.106000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE LOAD_ATTR append [ListIteratorVariable(length=4, index=1), ListVariable(length=0)]
# V0904 22:04:10.107000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE LOAD_FAST xi [ListIteratorVariable(length=4, index=1), GetAttrVariable()]
# V0904 22:04:10.108000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE LOAD_ATTR shape [ListIteratorVariable(length=4, index=1), GetAttrVariable(), TensorVariable()]
# V0904 22:04:10.108000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE LOAD_CONST 2 [ListIteratorVariable(length=4, index=1), GetAttrVariable(), SizeVariable(length=4)]
# V0904 22:04:10.109000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE LOAD_CONST 4 [ListIteratorVariable(length=4, index=1), GetAttrVariable(), SizeVariable(length=4), ConstantVariable()]
# V0904 22:04:10.109000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE BUILD_SLICE 2 [ListIteratorVariable(length=4, index=1), GetAttrVariable(), SizeVariable(length=4), ConstantVariable(), ConstantVariable()]
# V0904 22:04:10.110000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE BINARY_SUBSCR None [ListIteratorVariable(length=4, index=1), GetAttrVariable(), SizeVariable(length=4), SliceVariable()]
# V0904 22:04:10.111000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE CALL_FUNCTION 1 [ListIteratorVariable(length=4, index=1), GetAttrVariable(), SizeVariable(length=2)]
# V0904 22:04:10.112000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE POP_TOP None [ListIteratorVariable(length=4, index=1), ConstantVariable()]
# V0904 22:04:10.112000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE JUMP_ABSOLUTE 12 [ListIteratorVariable(length=4, index=1)]
# V0904 22:04:10.113000 440 torch/_dynamo/symbolic_convert.py:865] [9/0] [__trace_source] TRACE starts_line /var/folders/rk/fqb5s6dn6sl66ntxp1ssybz80000gn/T/ipykernel_440/1310961134.py:7 in forward
# V0904 22:04:10.113000 440 torch/_dynamo/symbolic_convert.py:865] [9/0] [__trace_source]             for i, xi in enumerate(x):
# V0904 22:04:10.113000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE FOR_ITER 42 [ListIteratorVariable(length=4, index=1)]
# V0904 22:04:10.114000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE UNPACK_SEQUENCE 2 [ListIteratorVariable(length=4, index=2), TupleVariable(length=2)]
# V0904 22:04:10.114000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE STORE_FAST i [ListIteratorVariable(length=4, index=2), TensorVariable(), ConstantVariable()]
# V0904 22:04:10.115000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE STORE_FAST xi [ListIteratorVariable(length=4, index=2), TensorVariable()]
# V0904 22:04:10.115000 440 torch/_dynamo/symbolic_convert.py:865] [9/0] [__trace_source] TRACE starts_line /var/folders/rk/fqb5s6dn6sl66ntxp1ssybz80000gn/T/ipykernel_440/1310961134.py:8 in forward
# V0904 22:04:10.115000 440 torch/_dynamo/symbolic_convert.py:865] [9/0] [__trace_source]                 spatial_shapes.append(xi.shape[2:4])  # C1: tuple casting
# V0904 22:04:10.116000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE LOAD_FAST spatial_shapes [ListIteratorVariable(length=4, index=2)]
# V0904 22:04:10.116000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE LOAD_ATTR append [ListIteratorVariable(length=4, index=2), ListVariable(length=1)]
# V0904 22:04:10.117000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE LOAD_FAST xi [ListIteratorVariable(length=4, index=2), GetAttrVariable()]
# V0904 22:04:10.117000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE LOAD_ATTR shape [ListIteratorVariable(length=4, index=2), GetAttrVariable(), TensorVariable()]
# V0904 22:04:10.118000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE LOAD_CONST 2 [ListIteratorVariable(length=4, index=2), GetAttrVariable(), SizeVariable(length=4)]
# V0904 22:04:10.118000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE LOAD_CONST 4 [ListIteratorVariable(length=4, index=2), GetAttrVariable(), SizeVariable(length=4), ConstantVariable()]
# V0904 22:04:10.119000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE BUILD_SLICE 2 [ListIteratorVariable(length=4, index=2), GetAttrVariable(), SizeVariable(length=4), ConstantVariable(), ConstantVariable()]
# V0904 22:04:10.119000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE BINARY_SUBSCR None [ListIteratorVariable(length=4, index=2), GetAttrVariable(), SizeVariable(length=4), SliceVariable()]
# V0904 22:04:10.120000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE CALL_FUNCTION 1 [ListIteratorVariable(length=4, index=2), GetAttrVariable(), SizeVariable(length=2)]
# V0904 22:04:10.121000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE POP_TOP None [ListIteratorVariable(length=4, index=2), ConstantVariable()]
# V0904 22:04:10.121000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE JUMP_ABSOLUTE 12 [ListIteratorVariable(length=4, index=2)]
# V0904 22:04:10.122000 440 torch/_dynamo/symbolic_convert.py:865] [9/0] [__trace_source] TRACE starts_line /var/folders/rk/fqb5s6dn6sl66ntxp1ssybz80000gn/T/ipykernel_440/1310961134.py:7 in forward
# V0904 22:04:10.122000 440 torch/_dynamo/symbolic_convert.py:865] [9/0] [__trace_source]             for i, xi in enumerate(x):
# V0904 22:04:10.122000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE FOR_ITER 42 [ListIteratorVariable(length=4, index=2)]
# V0904 22:04:10.123000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE UNPACK_SEQUENCE 2 [ListIteratorVariable(length=4, index=3), TupleVariable(length=2)]
# V0904 22:04:10.123000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE STORE_FAST i [ListIteratorVariable(length=4, index=3), TensorVariable(), ConstantVariable()]
# V0904 22:04:10.123000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE STORE_FAST xi [ListIteratorVariable(length=4, index=3), TensorVariable()]
# V0904 22:04:10.124000 440 torch/_dynamo/symbolic_convert.py:865] [9/0] [__trace_source] TRACE starts_line /var/folders/rk/fqb5s6dn6sl66ntxp1ssybz80000gn/T/ipykernel_440/1310961134.py:8 in forward
# V0904 22:04:10.124000 440 torch/_dynamo/symbolic_convert.py:865] [9/0] [__trace_source]                 spatial_shapes.append(xi.shape[2:4])  # C1: tuple casting
# V0904 22:04:10.124000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE LOAD_FAST spatial_shapes [ListIteratorVariable(length=4, index=3)]
# V0904 22:04:10.125000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE LOAD_ATTR append [ListIteratorVariable(length=4, index=3), ListVariable(length=2)]
# V0904 22:04:10.125000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE LOAD_FAST xi [ListIteratorVariable(length=4, index=3), GetAttrVariable()]
# V0904 22:04:10.126000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE LOAD_ATTR shape [ListIteratorVariable(length=4, index=3), GetAttrVariable(), TensorVariable()]
# V0904 22:04:10.127000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE LOAD_CONST 2 [ListIteratorVariable(length=4, index=3), GetAttrVariable(), SizeVariable(length=4)]
# V0904 22:04:10.127000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE LOAD_CONST 4 [ListIteratorVariable(length=4, index=3), GetAttrVariable(), SizeVariable(length=4), ConstantVariable()]
# V0904 22:04:10.128000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE BUILD_SLICE 2 [ListIteratorVariable(length=4, index=3), GetAttrVariable(), SizeVariable(length=4), ConstantVariable(), ConstantVariable()]
# V0904 22:04:10.128000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE BINARY_SUBSCR None [ListIteratorVariable(length=4, index=3), GetAttrVariable(), SizeVariable(length=4), SliceVariable()]
# V0904 22:04:10.129000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE CALL_FUNCTION 1 [ListIteratorVariable(length=4, index=3), GetAttrVariable(), SizeVariable(length=2)]
# V0904 22:04:10.130000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE POP_TOP None [ListIteratorVariable(length=4, index=3), ConstantVariable()]
# V0904 22:04:10.130000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE JUMP_ABSOLUTE 12 [ListIteratorVariable(length=4, index=3)]
# V0904 22:04:10.131000 440 torch/_dynamo/symbolic_convert.py:865] [9/0] [__trace_source] TRACE starts_line /var/folders/rk/fqb5s6dn6sl66ntxp1ssybz80000gn/T/ipykernel_440/1310961134.py:7 in forward
# V0904 22:04:10.131000 440 torch/_dynamo/symbolic_convert.py:865] [9/0] [__trace_source]             for i, xi in enumerate(x):
# V0904 22:04:10.131000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE FOR_ITER 42 [ListIteratorVariable(length=4, index=3)]
# V0904 22:04:10.132000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE UNPACK_SEQUENCE 2 [ListIteratorVariable(length=4, index=4), TupleVariable(length=2)]
# V0904 22:04:10.133000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE STORE_FAST i [ListIteratorVariable(length=4, index=4), TensorVariable(), ConstantVariable()]
# V0904 22:04:10.133000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE STORE_FAST xi [ListIteratorVariable(length=4, index=4), TensorVariable()]
# V0904 22:04:10.134000 440 torch/_dynamo/symbolic_convert.py:865] [9/0] [__trace_source] TRACE starts_line /var/folders/rk/fqb5s6dn6sl66ntxp1ssybz80000gn/T/ipykernel_440/1310961134.py:8 in forward
# V0904 22:04:10.134000 440 torch/_dynamo/symbolic_convert.py:865] [9/0] [__trace_source]                 spatial_shapes.append(xi.shape[2:4])  # C1: tuple casting
# V0904 22:04:10.134000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE LOAD_FAST spatial_shapes [ListIteratorVariable(length=4, index=4)]
# V0904 22:04:10.135000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE LOAD_ATTR append [ListIteratorVariable(length=4, index=4), ListVariable(length=3)]
# V0904 22:04:10.135000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE LOAD_FAST xi [ListIteratorVariable(length=4, index=4), GetAttrVariable()]
# V0904 22:04:10.136000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE LOAD_ATTR shape [ListIteratorVariable(length=4, index=4), GetAttrVariable(), TensorVariable()]
# V0904 22:04:10.136000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE LOAD_CONST 2 [ListIteratorVariable(length=4, index=4), GetAttrVariable(), SizeVariable(length=4)]
# V0904 22:04:10.137000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE LOAD_CONST 4 [ListIteratorVariable(length=4, index=4), GetAttrVariable(), SizeVariable(length=4), ConstantVariable()]
# V0904 22:04:10.137000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE BUILD_SLICE 2 [ListIteratorVariable(length=4, index=4), GetAttrVariable(), SizeVariable(length=4), ConstantVariable(), ConstantVariable()]
# V0904 22:04:10.138000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE BINARY_SUBSCR None [ListIteratorVariable(length=4, index=4), GetAttrVariable(), SizeVariable(length=4), SliceVariable()]
# V0904 22:04:10.139000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE CALL_FUNCTION 1 [ListIteratorVariable(length=4, index=4), GetAttrVariable(), SizeVariable(length=2)]
# V0904 22:04:10.139000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE POP_TOP None [ListIteratorVariable(length=4, index=4), ConstantVariable()]
# V0904 22:04:10.139000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE JUMP_ABSOLUTE 12 [ListIteratorVariable(length=4, index=4)]
# V0904 22:04:10.140000 440 torch/_dynamo/symbolic_convert.py:865] [9/0] [__trace_source] TRACE starts_line /var/folders/rk/fqb5s6dn6sl66ntxp1ssybz80000gn/T/ipykernel_440/1310961134.py:7 in forward
# V0904 22:04:10.140000 440 torch/_dynamo/symbolic_convert.py:865] [9/0] [__trace_source]             for i, xi in enumerate(x):
# V0904 22:04:10.140000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE FOR_ITER 42 [ListIteratorVariable(length=4, index=4)]
# V0904 22:04:10.141000 440 torch/_dynamo/symbolic_convert.py:865] [9/0] [__trace_source] TRACE starts_line /var/folders/rk/fqb5s6dn6sl66ntxp1ssybz80000gn/T/ipykernel_440/1310961134.py:12 in forward
# V0904 22:04:10.141000 440 torch/_dynamo/symbolic_convert.py:865] [9/0] [__trace_source]             spatial_shapes = array.array("i", spatial_shapes)
# V0904 22:04:10.142000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE LOAD_GLOBAL array []
# V0904 22:04:10.142000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE LOAD_ATTR array [PythonModuleVariable(<module 'array' from '/Users/dgcnz/.pyenv/versions/3.10.12/lib/python3.10/lib-dynload/array.cpython-310-darwin.so'>)]
# V0904 22:04:10.144000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE LOAD_CONST i [UserDefinedClassVariable()]
# V0904 22:04:10.144000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE LOAD_FAST spatial_shapes [UserDefinedClassVariable(), ConstantVariable()]
# V0904 22:04:10.145000 440 torch/_dynamo/symbolic_convert.py:888] [9/0] [__trace_bytecode] TRACE CALL_FUNCTION 2 [UserDefinedClassVariable(), ConstantVariable(), ListVariable(length=4)]
# V0904 22:04:10.146000 440 torch/_dynamo/symbolic_convert.py:904] [9/0] empty checkpoint
# ---------------------------------------------------------------------------
# Unsupported                               Traceback (most recent call last)
# Cell In[98], line 1
# ----> 1 exported_program: torch.export.ExportedProgram = torch.export.export(
#       2     NetMRE(), (), kwargs=example_kwargs, strict=True,
#       3 )
#       4 print(exported_program)
#
# File ~/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/export/__init__.py:258, in export(mod, args, kwargs, dynamic_shapes, strict, preserve_module_call_signature)
# ...
#     104     with unset_fake_temporarily():
# --> 105         return fn(*args, **kwargs)
#
# File ~/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/export/_trace.py:1915, in _export(mod, args, kwargs, dynamic_shapes, strict, preserve_module_call_signature, pre_dispatch, allow_complex_guards_as_runtime_asserts, _is_torch_jit_trace)
#    1912 # Call the appropriate export function based on the strictness of tracing.
#    1913 export_func = _strict_export if strict else _non_strict_export
# -> 1915 export_artifact = export_func(  # type: ignore[operator]
#    1916     mod,
#    1917     args,
#    1918     kwargs,
#    1919     dynamic_shapes,
#    1920     preserve_module_call_signature,
#    1921     pre_dispatch,
#    1922     original_state_dict,
#    1923     original_in_spec,
#    1924     allow_complex_guards_as_runtime_asserts,
#    1925     _is_torch_jit_trace,
#    1926 )
#    1927 export_graph_signature: ExportGraphSignature = export_artifact.aten.sig
#    1929 forward_arg_names = (
#    1930     _get_forward_arg_names(mod, args, kwargs) if not _is_torch_jit_trace else None
#    1931 )
#
# File ~/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/export/_trace.py:1214, in _strict_export(mod, args, kwargs, dynamic_shapes, preserve_module_call_signature, pre_dispatch, original_state_dict, orig_in_spec, allow_complex_guards_as_runtime_asserts, _is_torch_jit_trace)
#    1201 def _strict_export(
#    1202     mod: torch.nn.Module,
#    1203     args: Tuple[Any, ...],
#    (...)
#    1211     _is_torch_jit_trace: bool,
#    1212 ) -> ExportArtifact:
#    1213     lower_to_aten = functools.partial(_export_to_aten_ir, pre_dispatch=pre_dispatch)
# -> 1214     return _strict_export_lower_to_aten_ir(
#    1215         mod=mod,
#    1216         args=args,
#    1217         kwargs=kwargs,
#    1218         dynamic_shapes=dynamic_shapes,
#    1219         preserve_module_call_signature=preserve_module_call_signature,
#    1220         pre_dispatch=pre_dispatch,
#    1221         original_state_dict=original_state_dict,
#    1222         orig_in_spec=orig_in_spec,
#    1223         allow_complex_guards_as_runtime_asserts=allow_complex_guards_as_runtime_asserts,
#    1224         _is_torch_jit_trace=_is_torch_jit_trace,
#    1225         lower_to_aten_callback=lower_to_aten,
#    1226     )
#
# File ~/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/export/_trace.py:1242, in _strict_export_lower_to_aten_ir(mod, args, kwargs, dynamic_shapes, preserve_module_call_signature, pre_dispatch, original_state_dict, orig_in_spec, allow_complex_guards_as_runtime_asserts, _is_torch_jit_trace, lower_to_aten_callback)
#    1229 def _strict_export_lower_to_aten_ir(
#    1230     mod: torch.nn.Module,
#    1231     args: Tuple[Any, ...],
#    (...)
#    1240     lower_to_aten_callback: Callable,
#    1241 ) -> ExportArtifact:
# -> 1242     gm_torch_level = _export_to_torch_ir(
#    1243         mod,
#    1244         args,
#    1245         kwargs,
#    1246         dynamic_shapes,
#    1247         preserve_module_call_signature=preserve_module_call_signature,
#    1248         restore_fqn=False,  # don't need to restore because we will do it later
#    1249         allow_complex_guards_as_runtime_asserts=allow_complex_guards_as_runtime_asserts,
#    1250         _log_export_usage=False,
#    1251     )
#    1253     # We detect the fake_mode by looking at gm_torch_level's placeholders, this is the fake_mode created in dynamo.
#    1254     (
#    1255         fake_args,
#    1256         fake_kwargs,
#    1257         dynamo_fake_mode,
#    1258     ) = _extract_fake_inputs(gm_torch_level, args, kwargs)
#
# File ~/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/export/_trace.py:550, in _export_to_torch_ir(f, args, kwargs, dynamic_shapes, preserve_module_call_signature, disable_constraint_solver, allow_complex_guards_as_runtime_asserts, restore_fqn, _log_export_usage, same_signature)
#     546     module_call_specs: Dict[str, Dict[str, pytree.TreeSpec]] = {}
#     547     with _wrap_submodules(
#     548         f, preserve_module_call_signature, module_call_specs
#     549     ), _ignore_backend_decomps():
# --> 550         gm_torch_level, _ = torch._dynamo.export(
#     551             f,
#     552             dynamic_shapes=_dynamic_shapes,  # type: ignore[arg-type]
#     553             tracing_mode="symbolic",
#     554             disable_constraint_solver=disable_constraint_solver,
#     555             # currently the following 2 flags are tied together for export purposes,
#     556             # but untangle for sake of dynamo export api
#     557             prefer_deferred_runtime_asserts_over_guards=True,
#     558             allow_complex_guards_as_runtime_asserts=allow_complex_guards_as_runtime_asserts,
#     559             _log_export_usage=_log_export_usage,
#     560             same_signature=same_signature,
#     561         )(
#     562             *args,
#     563             **kwargs,
#     564         )
#     565 except (ConstraintViolationError, ValueRangeError) as e:
#     566     raise UserError(UserErrorType.CONSTRAINT_VIOLATION, str(e))  # noqa: B904
#
# File ~/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/_dynamo/eval_frame.py:1432, in export.<locals>.inner(*args, **kwargs)
#    1430 # TODO(voz): We may have instances of `f` that mutate inputs, we should track sideeffects and reject.
#    1431 try:
# -> 1432     result_traced = opt_f(*args, **kwargs)
#    1433 except ConstraintViolationError as e:
#    1434     constraint_violation_error = e
#
# File ~/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/_dynamo/eval_frame.py:465, in _TorchDynamoContext.__call__.<locals>._fn(*args, **kwargs)
#     460 saved_dynamic_layer_stack_depth = (
#     461     torch._C._functorch.get_dynamic_layer_stack_depth()
#     462 )
#     464 try:
# --> 465     return fn(*args, **kwargs)
#     466 finally:
#     467     # Restore the dynamic layer stack depth if necessary.
#     468     torch._C._functorch.pop_dynamic_layer_stack_and_undo_to_depth(
#     469         saved_dynamic_layer_stack_depth
#     470     )
#
# File ~/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/_dynamo/convert_frame.py:1251, in CatchErrorsWrapper.__call__(self, frame, cache_entry, frame_state)
#    1245             return hijacked_callback(
#    1246                 frame, cache_entry, self.hooks, frame_state
#    1247             )
#    1249 with compile_lock, _disable_current_modes():
#    1250     # skip=1: skip this frame
# -> 1251     return self._torchdynamo_orig_callable(
#    1252         frame, cache_entry, self.hooks, frame_state, skip=1
#    1253     )
#
# File ~/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/_dynamo/convert_frame.py:523, in ConvertFrameAssert.__call__(self, frame, cache_entry, hooks, frame_state, skip)
#     507 compile_id = CompileId(frame_id, frame_compile_id)
#     509 signpost_event(
#     510     "dynamo",
#     511     "_convert_frame_assert._compile",
#    (...)
#     520     },
#     521 )
# --> 523 return _compile(
#     524     frame.f_code,
#     525     frame.f_globals,
#     526     frame.f_locals,
#     527     frame.f_builtins,
#     528     self._torchdynamo_orig_callable,
#     529     self._one_graph,
#     530     self._export,
#     531     self._export_constraints,
#     532     hooks,
#     533     cache_entry,
#     534     cache_size,
#     535     frame,
#     536     frame_state=frame_state,
#     537     compile_id=compile_id,
#     538     skip=skip + 1,
#     539 )
#
# File ~/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/_dynamo/convert_frame.py:915, in _compile(code, globals, locals, builtins, compiler_fn, one_graph, export, export_constraints, hooks, cache_entry, cache_size, frame, frame_state, compile_id, skip)
#     913 guarded_code = None
#     914 try:
# --> 915     guarded_code = compile_inner(code, one_graph, hooks, transform)
#     916     return guarded_code
#     917 except (
#     918     Unsupported,
#     919     TorchRuntimeError,
#    (...)
#     926     BisectValidationException,
#     927 ) as e:
#
# File ~/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/_dynamo/convert_frame.py:663, in _compile.<locals>.compile_inner(code, one_graph, hooks, transform)
#     661 with dynamo_timed("_compile.compile_inner", phase_name="entire_frame_compile"):
#     662     with CompileTimeInstructionCounter.record():
# --> 663         return _compile_inner(code, one_graph, hooks, transform)
#
# File ~/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/_utils_internal.py:87, in compile_time_strobelight_meta.<locals>.compile_time_strobelight_meta_inner.<locals>.wrapper_function(*args, **kwargs)
#      84     kwargs["skip"] = kwargs["skip"] + 1
#      86 if not StrobelightCompileTimeProfiler.enabled:
# ---> 87     return function(*args, **kwargs)
#      89 return StrobelightCompileTimeProfiler.profile_compile_time(
#      90     function, phase_name, *args, **kwargs
#      91 )
#
# File ~/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/_dynamo/convert_frame.py:696, in _compile.<locals>._compile_inner(code, one_graph, hooks, transform)
#     694 CompileContext.get().attempt = attempt
#     695 try:
# --> 696     out_code = transform_code_object(code, transform)
#     697     break
#     698 except exc.RestartAnalysis as e:
#
# File ~/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/_dynamo/bytecode_transformation.py:1322, in transform_code_object(code, transformations, safe)
#    1319 instructions = cleaned_instructions(code, safe)
#    1320 propagate_line_nums(instructions)
# -> 1322 transformations(instructions, code_options)
#    1323 return clean_and_assemble_instructions(instructions, keys, code_options)[1]
#
# File ~/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/_dynamo/convert_frame.py:216, in preserve_global_state.<locals>._fn(*args, **kwargs)
#     212 exit_stack.enter_context(
#     213     torch.fx._symbolic_trace._maybe_revert_all_patches()
#     214 )
#     215 try:
# --> 216     return fn(*args, **kwargs)
#     217 finally:
#     218     cleanup.close()
#
# File ~/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/_dynamo/convert_frame.py:631, in _compile.<locals>.transform(instructions, code_options)
#     629 try:
#     630     with tracing(tracer.output.tracing_context), tracer.set_current_tx():
# --> 631         tracer.run()
#     632 except exc.UnspecializeRestartAnalysis:
#     633     speculation_log.clear()
#
# File ~/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/_dynamo/symbolic_convert.py:2796, in InstructionTranslator.run(self)
#    2795 def run(self):
# -> 2796     super().run()
#
# File ~/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/_dynamo/symbolic_convert.py:983, in InstructionTranslatorBase.run(self)
#     981 try:
#     982     self.output.push_tx(self)
# --> 983     while self.step():
#     984         pass
#     985 except BackendCompilerFailed:
#
# File ~/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/_dynamo/symbolic_convert.py:895, in InstructionTranslatorBase.step(self)
#     892 self.update_block_stack(inst)
#     894 try:
# --> 895     self.dispatch_table[inst.opcode](self, inst)
#     896     return not self.output.should_exit
#     897 except exc.ObservedException as e:
#
# File ~/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/_dynamo/symbolic_convert.py:582, in break_graph_if_unsupported.<locals>.decorator.<locals>.wrapper(self, inst)
#     580     return handle_graph_break(self, inst, speculation.reason)
#     581 try:
# --> 582     return inner_fn(self, inst)
#     583 except Unsupported as excp:
#     584     if self.generic_context_manager_depth > 0:
#     585         # We don't support graph break under GenericContextWrappingVariable,
#     586         # If there is, we roll back to the checkpoint and fall back.
#
# File ~/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/_dynamo/symbolic_convert.py:1602, in InstructionTranslatorBase.CALL_FUNCTION(self, inst)
#    1600 args = self.popn(inst.argval)
#    1601 fn = self.pop()
# -> 1602 self.call_function(fn, args, {})
#
# File ~/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/_dynamo/symbolic_convert.py:830, in InstructionTranslatorBase.call_function(self, fn, args, kwargs)
#     828 if inner_fn and callable(inner_fn) and is_forbidden(inner_fn):
#     829     raise AssertionError(f"Attempt to trace forbidden callable {inner_fn}")
# --> 830 self.push(fn.call_function(self, args, kwargs))
#
# File ~/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/_dynamo/variables/user_defined.py:534, in UserDefinedClassVariable.call_function(self, tx, args, kwargs)
#     521 elif (
#     522     not self.is_standard_new()
#     523     and SideEffects.cls_supports_mutation_side_effects(self.value)
#     524     and self.source
#     525 ):
#     526     return tx.inline_user_function_return(
#     527         SourcelessBuilder.create(
#     528             tx, polyfills.instantiate_user_defined_class_object
#    (...)
#     531         kwargs,
#     532     )
# --> 534 return super().call_function(tx, args, kwargs)
#
# File ~/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/_dynamo/variables/base.py:308, in VariableTracker.call_function(self, tx, args, kwargs)
#     302 def call_function(
#     303     self,
#     304     tx: "InstructionTranslator",
#     305     args: "List[VariableTracker]",
#     306     kwargs: "Dict[str, VariableTracker]",
#     307 ) -> "VariableTracker":
# --> 308     unimplemented(f"call_function {self} {args} {kwargs}")
#
# File ~/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/_dynamo/exc.py:289, in unimplemented(msg, from_exc, case_name)
#     287 if from_exc is not _NOTHING:
#     288     raise Unsupported(msg, case_name=case_name) from from_exc
# --> 289 raise Unsupported(msg, case_name=case_name)
#
# Unsupported: call_function UserDefinedClassVariable(<class 'array.array'>) [ConstantVariable(), ListVariable(length=4)] {}
#
# from user code:
#    File "/var/folders/rk/fqb5s6dn6sl66ntxp1ssybz80000gn/T/ipykernel_440/1310961134.py", line 12, in forward
#     spatial_shapes = array.array("i", spatial_shapes)

# %%
dynamo.config.verbose=False
dynamo.config.capture_scalar_outputs = True
torch._logging.set_logs(dynamo = logging.WARN)

explanation = dynamo.explain(NetMRE())(**example_kwargs)
print(explanation.break_reasons[0])

# %% [markdown]
# This error basically tells us that we are trying to compute something (creating the tensor `lin`) whose values and more importantly, shape, is dependent on whatever values the `spatial_shapes` tensor contains.
#
# However, this should not be the case, since `spatial_shapes` are the shapes of the input tensor, which we know to be constant.

# %% [markdown]
# ## C2: Avoiding extra tensor casting
#
# A simple fix is to not cast `spatial_shapes` into a tensor, but that doesn't seem satisfactory and would require further rewrites in the actual code that use the tensor methods like `spatial_shapes.your_nice_tensor_method`. Anyway, let's do that to see what changes.

# %%
class NetC2(nn.Module):
    def forward(self, x: typing.List[torch.Tensor]):
        spatial_shapes: typing.List[typing.Tuple[int, int]] = []
        for i, xi in enumerate(x):
            spatial_shapes.append(tuple(xi.shape[2:]))
        reference_points = self.get_reference_points(spatial_shapes)
        return reference_points

    @staticmethod
    def get_reference_points(
        spatial_shapes: typing.List[typing.Tuple[int, int]],
    ): 
        reference_points_list = []
        for H, W in spatial_shapes:
            lin = torch.linspace(0.5, H - 0.5, H, dtype=torch.float32)
            reference_points_list.append(lin)
        return reference_points_list

# %%
dynamo.config.verbose=False
dynamo.config.capture_scalar_outputs = True
torch._logging.set_logs(dynamo = logging.WARN)

explanation = dynamo.explain(NetC2())(**example_kwargs)
print(explanation)

# %%
dynamo.config.verbose=True
# dynamo.config.capture_scalar_outputs = True
# dynamo.config.capture_dynamic_output_shape_ops = True
# torch._dynamo.config.fake_tensor_cache_enabled = False
torch._logging.set_logs(dynamo = logging.INFO)

# explanation = dynamo.explain(NetC4v4())(**example_kwargs)
# print(explanation)
exported_program: torch.export.ExportedProgram = torch.export.export(
    NetC2(), (), kwargs=example_kwargs, strict=True,
)
print(exported_program)

# %% [markdown]
# ## C3

# %%
class NetC3(nn.Module):
    def forward(self, x: typing.List[torch.Tensor]):
        spatial_shapes: typing.List[typing.Tuple[int, int]] = []
        for i, xi in enumerate(x):
            spatial_shapes.append(xi.shape[2:])
        spatial_shapes_tensor: typing.Final[torch.Tensor] = torch.as_tensor(spatial_shapes, dtype=torch.long)
        reference_points = self.get_reference_points(spatial_shapes_tensor)
        return reference_points

    @staticmethod
    def get_reference_points(
        spatial_shapes: torch.Tensor,
    ): 
        reference_points_list = []
        for H, W in spatial_shapes:
            lin = torch.linspace(0.5, H - 0.5, H, dtype=torch.float32) # --- breaks here
            reference_points_list.append(lin)
        return reference_points_list

# %%
dynamo.config.verbose=False
dynamo.config.capture_scalar_outputs = True
torch._logging.set_logs(dynamo = logging.WARN)

explanation = dynamo.explain(NetC3())(**example_kwargs)
print(explanation.break_reasons[0].reason)

# %%
import torch._dynamo.variables as dynamo_vars

class NetC4v2(nn.Module):

    def forward(self, x: typing.List[torch.Tensor]):
        spatial_shapes: typing.List[typing.Tuple[int, int]] = []
        for i, xi in enumerate(x):
            spatial_shapes.append(xi.shape[2:])
        spatial_shapes_tensor = torch.as_tensor(spatial_shapes, dtype=torch.long)

        # Tried:
        # dynamo.assume_constant_result
        spatial_shapes_tensor._dynamo_marked_constant = True
        spatial_shapes_tensor._dynamo_static_input_type = "unguarded"
        reference_points_list = []
        for H, W in spatial_shapes_tensor:
            lin = torch.linspace(0.5, H - 0.5, H, dtype=torch.float32) # --- breaks here
            reference_points_list.append(lin)
        return reference_points_list

# %%
dynamo.config.verbose=False
dynamo.config.capture_scalar_outputs = True
torch._logging.set_logs(dynamo = logging.INFO)

explanation = dynamo.explain(NetC4v2())(**example_kwargs)
print(explanation)

# %% [markdown]
# Surprisingly, even if we

# %%
from torch._subclasses.fake_tensor import FakeTensor, FakeTensorConverter, FakeTensorMode, unset_fake_temporarily
from torch._subclasses.functional_tensor import FunctionalTensor, disable_functional_mode
from torch._dynamo.variables import TensorVariable
import numpy as np
from torch.fx.experimental.proxy_tensor import maybe_disable_fake_tensor_mode
from torch._dispatch.python import suspend_functionalization
from torch.fx.experimental.proxy_tensor import disable_proxy_modes_tracing
class NetC4v4(nn.Module):

    def __init__(self):
        super().__init__()
        # self.ss: typing.Final[typing.List[typing.Tuple[int, int]]] =[(150, 100), (75, 50), (37, 25), (19, 13)]
        # self.sst: typing.Final[torch.Tensor] = torch.tensor(self.ss)
    def forward(self, x: typing.List[torch.Tensor]):
        # dynamo.decorators.mark_static(self.sst)
        with unset_fake_temporarily():
            with suspend_functionalization(), disable_functional_mode():
                with disable_proxy_modes_tracing():
                    sst = [(150, 100), (75, 50), (37, 25), (19, 13)]
                    ss = torch.tensor(sst) 
        reference_points_list = []
        for i in range(len(ss)):
            # h = sst.constant[i][0]
            # torch._check(h == ss[i][0])
            with unset_fake_temporarily():
                with suspend_functionalization(), disable_functional_mode():
                    with disable_proxy_modes_tracing():
                        h = int(ss[i][0])
            lin = torch.linspace(0.5, h  - 0.5, h)
            # torch._check(lin.shape[0] == sst[i][0])
            reference_points_list.append(lin)
        return reference_points_list

# %%
dynamo.config.verbose=True
dynamo.config.capture_scalar_outputs = True
dynamo.config.capture_dynamic_output_shape_ops = True
torch._dynamo.config.fake_tensor_cache_enabled = False
torch._logging.set_logs(dynamo = logging.INFO)

# explanation = dynamo.explain(NetC4v4())(**example_kwargs)
# print(explanation)
exported_program: torch.export.ExportedProgram = torch.export.export(
    NetC4v4(), (), kwargs=example_kwargs, strict=False,
)
print(exported_program)

# %%
from torch._subclasses.fake_tensor import FakeTensor, FakeTensorConverter, FakeTensorMode, unset_fake_temporarily
from torch._subclasses.functional_tensor import FunctionalTensor, disable_functional_mode
from torch._dynamo.variables import TensorVariable
import numpy as np
from torch.fx.experimental.proxy_tensor import maybe_disable_fake_tensor_mode
from torch._dispatch.python import suspend_functionalization
from torch.fx.experimental.proxy_tensor import disable_proxy_modes_tracing
class NetC4v5(nn.Module):

    def __init__(self):
        super().__init__()
        # self.ss: typing.Final[typing.List[typing.Tuple[int, int]]] =[(150, 100), (75, 50), (37, 25), (19, 13)]
        # self.sst: typing.Final[torch.Tensor] = torch.tensor(self.ss)
    def forward(self, x: typing.List[torch.Tensor]):
        # dynamo.decorators.mark_static(self.sst)
        with unset_fake_temporarily():
            # with suspend_functionalization(), disable_functional_mode():
                with disable_proxy_modes_tracing():
                    sst = [(150, 100), (75, 50), (37, 25), (19, 13)]
                    ss = torch.tensor(sst) 
        reference_points_list = []
        for i in range(len(ss)):
            # h = sst.constant[i][0]
            # torch._check(h == ss[i][0])
            with unset_fake_temporarily():
                # with suspend_functionalization(), disable_functional_mode():
                    with disable_proxy_modes_tracing():
                        h = int(ss[i][0])
            lin = torch.linspace(0.5, h  - 0.5, h)
            # torch._check(lin.shape[0] == sst[i][0])
            reference_points_list.append(lin)
        return reference_points_list

# %%
dynamo.config.verbose=True
dynamo.config.capture_scalar_outputs = True
dynamo.config.capture_dynamic_output_shape_ops = True
torch._dynamo.config.fake_tensor_cache_enabled = False
torch._logging.set_logs(dynamo = logging.INFO)

# explanation = dynamo.explain(NetC4v4())(**example_kwargs)
# print(explanation)
exported_program: torch.export.ExportedProgram = torch.export.export(
    NetC4v5(), (), kwargs=example_kwargs, strict=False,
)
print(exported_program)
# Out:
# I0821 19:57:27.517000 7923618560 torch/fx/experimental/symbolic_shapes.py:3639] produce_guards
# ExportedProgram:
#     class GraphModule(torch.nn.Module):
#         def forward(self, x_0: "f32[1, 3, 150, 100]", x_1: "f32[1, 3, 75, 50]", x_2: "f32[1, 3, 37, 25]", x_3: "f32[1, 3, 19, 13]"):
#             # File: /var/folders/rk/fqb5s6dn6sl66ntxp1ssybz80000gn/T/ipykernel_65943/2942393893.py:29 in forward, code: lin = torch.linspace(0.5, h  - 0.5, h)
#             linspace: "f32[150]" = torch.ops.aten.linspace.default(0.5, 149.5, 150, device = device(type='cpu'), pin_memory = False)
#             linspace_1: "f32[75]" = torch.ops.aten.linspace.default(0.5, 74.5, 75, device = device(type='cpu'), pin_memory = False)
#             linspace_2: "f32[37]" = torch.ops.aten.linspace.default(0.5, 36.5, 37, device = device(type='cpu'), pin_memory = False)
#             linspace_3: "f32[19]" = torch.ops.aten.linspace.default(0.5, 18.5, 19, device = device(type='cpu'), pin_memory = False)
#             return (linspace, linspace_1, linspace_2, linspace_3)
#
# Graph signature: ExportGraphSignature(input_specs=[InputSpec(kind=<InputKind.USER_INPUT: 1>, arg=TensorArgument(name='x_0'), target=None, persistent=None), InputSpec(kind=<InputKind.USER_INPUT: 1>, arg=TensorArgument(name='x_1'), target=None, persistent=None), InputSpec(kind=<InputKind.USER_INPUT: 1>, arg=TensorArgument(name='x_2'), target=None, persistent=None), InputSpec(kind=<InputKind.USER_INPUT: 1>, arg=TensorArgument(name='x_3'), target=None, persistent=None)], output_specs=[OutputSpec(kind=<OutputKind.USER_OUTPUT: 1>, arg=TensorArgument(name='linspace'), target=None), OutputSpec(kind=<OutputKind.USER_OUTPUT: 1>, arg=TensorArgument(name='linspace_1'), target=None), OutputSpec(kind=<OutputKind.USER_OUTPUT: 1>, arg=TensorArgument(name='linspace_2'), target=None), OutputSpec(kind=<OutputKind.USER_OUTPUT: 1>, arg=TensorArgument(name='linspace_3'), target=None)])
# Range constraints: {}

# %%
from torch._subclasses.fake_tensor import FakeTensor, FakeTensorConverter, FakeTensorMode, unset_fake_temporarily
from torch._subclasses.functional_tensor import FunctionalTensor, disable_functional_mode
from torch._dynamo.variables import TensorVariable
import numpy as np
from torch.fx.experimental.proxy_tensor import maybe_disable_fake_tensor_mode
from torch._dispatch.python import suspend_functionalization
from torch.fx.experimental.proxy_tensor import disable_proxy_modes_tracing
class NetC4v5(nn.Module):

    def __init__(self):
        super().__init__()
        # self.ss: typing.Final[typing.List[typing.Tuple[int, int]]] =[(150, 100), (75, 50), (37, 25), (19, 13)]
        # self.sst: typing.Final[torch.Tensor] = torch.tensor(self.ss)
    def forward(self, x: typing.List[torch.Tensor]):
        # dynamo.decorators.mark_static(self.sst)

        sst = [(150, 100), (75, 50), (37, 25), (19, 13)]
        with unset_fake_temporarily():
            # with suspend_functionalization(), disable_functional_mode():
                with disable_proxy_modes_tracing():
                    ss = torch.tensor(sst) 
        reference_points_list = []
        for i in range(len(ss)):
            # h = sst.constant[i][0]
            # torch._check(h == ss[i][0])
            with unset_fake_temporarily():
                # with suspend_functionalization(), disable_functional_mode():
                    with disable_proxy_modes_tracing():
                        h = int(ss[i][0])
            lin = torch.linspace(0.5, h  - 0.5, h)
            # torch._check(lin.shape[0] == sst[i][0])
            reference_points_list.append(lin)
        return reference_points_list

# %%
dynamo.config.verbose=True
# dynamo.config.capture_scalar_outputs = True
# dynamo.config.capture_dynamic_output_shape_ops = True
# torch._dynamo.config.fake_tensor_cache_enabled = False
torch._logging.set_logs(dynamo = logging.INFO)

# explanation = dynamo.explain(NetC4v4())(**example_kwargs)
# print(explanation)
exported_program: torch.export.ExportedProgram = torch.export.export(
    NetC4v5(), (), kwargs=example_kwargs, strict=False,
)
print(exported_program)
# Out:
# V0821 20:00:35.062000 7923618560 torch/fx/experimental/symbolic_shapes.py:2529] create_env
# I0821 20:00:35.085000 7923618560 torch/fx/experimental/symbolic_shapes.py:3639] produce_guards
# V0821 20:00:35.086000 7923618560 torch/fx/experimental/symbolic_shapes.py:3821] track_symint L['args'][1]['x'][0].size()[0] 1 None
# V0821 20:00:35.086000 7923618560 torch/fx/experimental/symbolic_shapes.py:3821] track_symint L['args'][1]['x'][0].size()[1] 3 None
# V0821 20:00:35.087000 7923618560 torch/fx/experimental/symbolic_shapes.py:3821] track_symint L['args'][1]['x'][0].size()[2] 150 None
# V0821 20:00:35.087000 7923618560 torch/fx/experimental/symbolic_shapes.py:3821] track_symint L['args'][1]['x'][0].size()[3] 100 None
# V0821 20:00:35.087000 7923618560 torch/fx/experimental/symbolic_shapes.py:3821] track_symint L['args'][1]['x'][0].stride()[0] 45000 None
# V0821 20:00:35.088000 7923618560 torch/fx/experimental/symbolic_shapes.py:3821] track_symint L['args'][1]['x'][0].stride()[1] 15000 None
# V0821 20:00:35.088000 7923618560 torch/fx/experimental/symbolic_shapes.py:3821] track_symint L['args'][1]['x'][0].stride()[2] 100 None
# V0821 20:00:35.088000 7923618560 torch/fx/experimental/symbolic_shapes.py:3821] track_symint L['args'][1]['x'][0].stride()[3] 1 None
# V0821 20:00:35.089000 7923618560 torch/fx/experimental/symbolic_shapes.py:3821] track_symint L['args'][1]['x'][0].storage_offset() 0 None
# V0821 20:00:35.089000 7923618560 torch/fx/experimental/symbolic_shapes.py:3821] track_symint L['args'][1]['x'][1].size()[0] 1 None
# V0821 20:00:35.090000 7923618560 torch/fx/experimental/symbolic_shapes.py:3821] track_symint L['args'][1]['x'][1].size()[1] 3 None
# V0821 20:00:35.090000 7923618560 torch/fx/experimental/symbolic_shapes.py:3821] track_symint L['args'][1]['x'][1].size()[2] 75 None
# V0821 20:00:35.090000 7923618560 torch/fx/experimental/symbolic_shapes.py:3821] track_symint L['args'][1]['x'][1].size()[3] 50 None
# V0821 20:00:35.091000 7923618560 torch/fx/experimental/symbolic_shapes.py:3821] track_symint L['args'][1]['x'][1].stride()[0] 11250 None
# V0821 20:00:35.091000 7923618560 torch/fx/experimental/symbolic_shapes.py:3821] track_symint L['args'][1]['x'][1].stride()[1] 3750 None
# V0821 20:00:35.092000 7923618560 torch/fx/experimental/symbolic_shapes.py:3821] track_symint L['args'][1]['x'][1].stride()[2] 50 None
# V0821 20:00:35.092000 7923618560 torch/fx/experimental/symbolic_shapes.py:3821] track_symint L['args'][1]['x'][1].stride()[3] 1 None
# V0821 20:00:35.093000 7923618560 torch/fx/experimental/symbolic_shapes.py:3821] track_symint L['args'][1]['x'][1].storage_offset() 0 None
# V0821 20:00:35.093000 7923618560 torch/fx/experimental/symbolic_shapes.py:3821] track_symint L['args'][1]['x'][2].size()[0] 1 None
# V0821 20:00:35.093000 7923618560 torch/fx/experimental/symbolic_shapes.py:3821] track_symint L['args'][1]['x'][2].size()[1] 3 None
# V0821 20:00:35.094000 7923618560 torch/fx/experimental/symbolic_shapes.py:3821] track_symint L['args'][1]['x'][2].size()[2] 37 None
# V0821 20:00:35.094000 7923618560 torch/fx/experimental/symbolic_shapes.py:3821] track_symint L['args'][1]['x'][2].size()[3] 25 None
# V0821 20:00:35.094000 7923618560 torch/fx/experimental/symbolic_shapes.py:3821] track_symint L['args'][1]['x'][2].stride()[0] 2775 None
# V0821 20:00:35.095000 7923618560 torch/fx/experimental/symbolic_shapes.py:3821] track_symint L['args'][1]['x'][2].stride()[1] 925 None
# V0821 20:00:35.095000 7923618560 torch/fx/experimental/symbolic_shapes.py:3821] track_symint L['args'][1]['x'][2].stride()[2] 25 None
# V0821 20:00:35.096000 7923618560 torch/fx/experimental/symbolic_shapes.py:3821] track_symint L['args'][1]['x'][2].stride()[3] 1 None
# V0821 20:00:35.096000 7923618560 torch/fx/experimental/symbolic_shapes.py:3821] track_symint L['args'][1]['x'][2].storage_offset() 0 None
# V0821 20:00:35.096000 7923618560 torch/fx/experimental/symbolic_shapes.py:3821] track_symint L['args'][1]['x'][3].size()[0] 1 None
# V0821 20:00:35.097000 7923618560 torch/fx/experimental/symbolic_shapes.py:3821] track_symint L['args'][1]['x'][3].size()[1] 3 None
# V0821 20:00:35.097000 7923618560 torch/fx/experimental/symbolic_shapes.py:3821] track_symint L['args'][1]['x'][3].size()[2] 19 None
# V0821 20:00:35.097000 7923618560 torch/fx/experimental/symbolic_shapes.py:3821] track_symint L['args'][1]['x'][3].size()[3] 13 None
# V0821 20:00:35.098000 7923618560 torch/fx/experimental/symbolic_shapes.py:3821] track_symint L['args'][1]['x'][3].stride()[0] 741 None
# V0821 20:00:35.098000 7923618560 torch/fx/experimental/symbolic_shapes.py:3821] track_symint L['args'][1]['x'][3].stride()[1] 247 None
# V0821 20:00:35.099000 7923618560 torch/fx/experimental/symbolic_shapes.py:3821] track_symint L['args'][1]['x'][3].stride()[2] 13 None
# V0821 20:00:35.099000 7923618560 torch/fx/experimental/symbolic_shapes.py:3821] track_symint L['args'][1]['x'][3].stride()[3] 1 None
# V0821 20:00:35.099000 7923618560 torch/fx/experimental/symbolic_shapes.py:3821] track_symint L['args'][1]['x'][3].storage_offset() 0 None
# ExportedProgram:
#     class GraphModule(torch.nn.Module):
#         def forward(self, x_0: "f32[1, 3, 150, 100]", x_1: "f32[1, 3, 75, 50]", x_2: "f32[1, 3, 37, 25]", x_3: "f32[1, 3, 19, 13]"):
#             # File: /var/folders/rk/fqb5s6dn6sl66ntxp1ssybz80000gn/T/ipykernel_65943/1980386621.py:30 in forward, code: lin = torch.linspace(0.5, h  - 0.5, h)
#             linspace: "f32[150]" = torch.ops.aten.linspace.default(0.5, 149.5, 150, device = device(type='cpu'), pin_memory = False)
#             linspace_1: "f32[75]" = torch.ops.aten.linspace.default(0.5, 74.5, 75, device = device(type='cpu'), pin_memory = False)
#             linspace_2: "f32[37]" = torch.ops.aten.linspace.default(0.5, 36.5, 37, device = device(type='cpu'), pin_memory = False)
#             linspace_3: "f32[19]" = torch.ops.aten.linspace.default(0.5, 18.5, 19, device = device(type='cpu'), pin_memory = False)
#             return (linspace, linspace_1, linspace_2, linspace_3)
#
# Graph signature: ExportGraphSignature(input_specs=[InputSpec(kind=<InputKind.USER_INPUT: 1>, arg=TensorArgument(name='x_0'), target=None, persistent=None), InputSpec(kind=<InputKind.USER_INPUT: 1>, arg=TensorArgument(name='x_1'), target=None, persistent=None), InputSpec(kind=<InputKind.USER_INPUT: 1>, arg=TensorArgument(name='x_2'), target=None, persistent=None), InputSpec(kind=<InputKind.USER_INPUT: 1>, arg=TensorArgument(name='x_3'), target=None, persistent=None)], output_specs=[OutputSpec(kind=<OutputKind.USER_OUTPUT: 1>, arg=TensorArgument(name='linspace'), target=None), OutputSpec(kind=<OutputKind.USER_OUTPUT: 1>, arg=TensorArgument(name='linspace_1'), target=None), OutputSpec(kind=<OutputKind.USER_OUTPUT: 1>, arg=TensorArgument(name='linspace_2'), target=None), OutputSpec(kind=<OutputKind.USER_OUTPUT: 1>, arg=TensorArgument(name='linspace_3'), target=None)])
# Range constraints: {}

# %%
dynamo.config.verbose=True
dynamo.config.capture_scalar_outputs = True
dynamo.config.capture_dynamic_output_shape_ops = True
torch._dynamo.config.fake_tensor_cache_enabled = False
torch._logging.set_logs(dynamo = logging.INFO)

exported_program: torch.export.ExportedProgram = torch.export.export(
    NetC2(), (), kwargs=example_kwargs, strict=False,
)
print(exported_program)
# Out:
# I0821 19:59:11.458000 7923618560 torch/fx/experimental/symbolic_shapes.py:3639] produce_guards
# ExportedProgram:
#     class GraphModule(torch.nn.Module):
#         def forward(self, x_0: "f32[1, 3, 150, 100]", x_1: "f32[1, 3, 75, 50]", x_2: "f32[1, 3, 37, 25]", x_3: "f32[1, 3, 19, 13]"):
#             # File: /var/folders/rk/fqb5s6dn6sl66ntxp1ssybz80000gn/T/ipykernel_65943/1787364395.py:6 in forward, code: reference_points = self.get_reference_points(spatial_shapes)
#             linspace: "f32[150]" = torch.ops.aten.linspace.default(0.5, 149.5, 150, dtype = torch.float32, device = device(type='cpu'), pin_memory = False)
#             linspace_1: "f32[75]" = torch.ops.aten.linspace.default(0.5, 74.5, 75, dtype = torch.float32, device = device(type='cpu'), pin_memory = False)
#             linspace_2: "f32[37]" = torch.ops.aten.linspace.default(0.5, 36.5, 37, dtype = torch.float32, device = device(type='cpu'), pin_memory = False)
#             linspace_3: "f32[19]" = torch.ops.aten.linspace.default(0.5, 18.5, 19, dtype = torch.float32, device = device(type='cpu'), pin_memory = False)
#             return (linspace, linspace_1, linspace_2, linspace_3)
#
# Graph signature: ExportGraphSignature(input_specs=[InputSpec(kind=<InputKind.USER_INPUT: 1>, arg=TensorArgument(name='x_0'), target=None, persistent=None), InputSpec(kind=<InputKind.USER_INPUT: 1>, arg=TensorArgument(name='x_1'), target=None, persistent=None), InputSpec(kind=<InputKind.USER_INPUT: 1>, arg=TensorArgument(name='x_2'), target=None, persistent=None), InputSpec(kind=<InputKind.USER_INPUT: 1>, arg=TensorArgument(name='x_3'), target=None, persistent=None)], output_specs=[OutputSpec(kind=<OutputKind.USER_OUTPUT: 1>, arg=TensorArgument(name='linspace'), target=None), OutputSpec(kind=<OutputKind.USER_OUTPUT: 1>, arg=TensorArgument(name='linspace_1'), target=None), OutputSpec(kind=<OutputKind.USER_OUTPUT: 1>, arg=TensorArgument(name='linspace_2'), target=None), OutputSpec(kind=<OutputKind.USER_OUTPUT: 1>, arg=TensorArgument(name='linspace_3'), target=None)])
# Range constraints: {}

# %%
class NetC2v2(nn.Module):
    def forward(self, x: typing.List[torch.Tensor]):
        spatial_shapes: typing.List[typing.Tuple[int, int]] = []
        for i, xi in enumerate(x):
            spatial_shapes.append(tuple(xi.shape[2:]))
        
        with unset_fake_temporarily():
            with disable_proxy_modes_tracing():
                spatial_shapes_tensor = torch.tensor(spatial_shapes, dtype=torch.long)
        reference_points = self.get_reference_points(spatial_shapes_tensor)
        return reference_points

    @staticmethod
    def get_reference_points(
        spatial_shapes: torch.Tensor,
    ): 
        reference_points_list = []
        for i in range(len(spatial_shapes)):
            with disable_proxy_modes_tracing():
                with unset_fake_temporarily():
                    h = int(spatial_shapes[i][0])
            lin = torch.linspace(0.5, h - 0.5, h, dtype=torch.float32)
            reference_points_list.append(lin)
        return reference_points_list

# %%
dynamo.config.verbose=True
dynamo.config.capture_scalar_outputs = True
dynamo.config.capture_dynamic_output_shape_ops = True
torch._dynamo.config.fake_tensor_cache_enabled = False
torch._logging.set_logs(dynamo = logging.INFO)

exported_program: torch.export.ExportedProgram = torch.export.export(
    NetC2v2(), (), kwargs=example_kwargs, strict=False,
)
print(exported_program)
# Out:
# I0821 20:57:12.049000 7923618560 torch/fx/experimental/symbolic_shapes.py:3639] produce_guards
# ExportedProgram:
#     class GraphModule(torch.nn.Module):
#         def forward(self, x_0: "f32[1, 3, 150, 100]", x_1: "f32[1, 3, 75, 50]", x_2: "f32[1, 3, 37, 25]", x_3: "f32[1, 3, 19, 13]"):
#             # File: /var/folders/rk/fqb5s6dn6sl66ntxp1ssybz80000gn/T/ipykernel_84265/4072546233.py:10 in forward, code: reference_points = self.get_reference_points(spatial_shapes_tensor)
#             linspace: "f32[150]" = torch.ops.aten.linspace.default(0.5, 149.5, 150, dtype = torch.float32, device = device(type='cpu'), pin_memory = False)
#             linspace_1: "f32[75]" = torch.ops.aten.linspace.default(0.5, 74.5, 75, dtype = torch.float32, device = device(type='cpu'), pin_memory = False)
#             linspace_2: "f32[37]" = torch.ops.aten.linspace.default(0.5, 36.5, 37, dtype = torch.float32, device = device(type='cpu'), pin_memory = False)
#             linspace_3: "f32[19]" = torch.ops.aten.linspace.default(0.5, 18.5, 19, dtype = torch.float32, device = device(type='cpu'), pin_memory = False)
#             return (linspace, linspace_1, linspace_2, linspace_3)
#
# Graph signature: ExportGraphSignature(input_specs=[InputSpec(kind=<InputKind.USER_INPUT: 1>, arg=TensorArgument(name='x_0'), target=None, persistent=None), InputSpec(kind=<InputKind.USER_INPUT: 1>, arg=TensorArgument(name='x_1'), target=None, persistent=None), InputSpec(kind=<InputKind.USER_INPUT: 1>, arg=TensorArgument(name='x_2'), target=None, persistent=None), InputSpec(kind=<InputKind.USER_INPUT: 1>, arg=TensorArgument(name='x_3'), target=None, persistent=None)], output_specs=[OutputSpec(kind=<OutputKind.USER_OUTPUT: 1>, arg=TensorArgument(name='linspace'), target=None), OutputSpec(kind=<OutputKind.USER_OUTPUT: 1>, arg=TensorArgument(name='linspace_1'), target=None), OutputSpec(kind=<OutputKind.USER_OUTPUT: 1>, arg=TensorArgument(name='linspace_2'), target=None), OutputSpec(kind=<OutputKind.USER_OUTPUT: 1>, arg=TensorArgument(name='linspace_3'), target=None)])
# Range constraints: {}

# %%
from torch._subclasses.fake_tensor import FakeTensor, FakeTensorConverter, FakeTensorMode, unset_fake_temporarily
from torch._subclasses.functional_tensor import FunctionalTensor, disable_functional_mode
from torch._dynamo.variables import TensorVariable
import numpy as np
from torch._dispatch.python import suspend_functionalization
from torch.utils._python_dispatch import _unset_infra_mode, _push_mode
from torch.fx.experimental.proxy_tensor import disable_proxy_modes_tracing
import torch.nn as nn
import torch._dynamo as dynamo
import typing
import torch
import logging

class NetC4v6(nn.Module):

    def __init__(self):
        super().__init__()
        # self.ss: typing.Final[typing.List[typing.Tuple[int, int]]] =[(150, 100), (75, 50), (37, 25), (19, 13)]
        # old = torch._C._unset_dispatch_mode(torch._C._TorchDispatchModeKey.FAKE)
        # with disable_proxy_modes_tracing():
        # self.sst: typing.Final[torch.Tensor] = torch.tensor(self.ss)
    def forward(self, x: typing.List[torch.Tensor]):
        ss: typing.List[typing.Tuple[int, int]] =[(150, 100), (75, 50), (37, 25), (19, 13)]
        # old = torch._C._unset_dispatch_mode(torch._C._TorchDispatchModeKey.FAKE)
        # with disable_proxy_modes_tracing():

        old = torch._C._unset_dispatch_mode(torch._C._TorchDispatchModeKey.FAKE)
        # with unset_fake_temporarily():
        # with disable_proxy_modes_tracing():
        # return _disable_infra_mode(torch._C._TorchDispatchModeKey.PROXY)
        sst: torch.Tensor = torch.as_tensor(ss)
        torch._C._set_dispatch_mode(old)
        # dynamo.decorators.mark_static(sst)
        reference_points_list = []
        for i in range(len(sst)):
            old = torch._C._unset_dispatch_mode(torch._C._TorchDispatchModeKey.FAKE)
            mode_unset = _unset_infra_mode(torch._C._TorchDispatchModeKey.PROXY)
            h = int(sst[i][0])
            _push_mode(mode_unset)
            # torch._C._push_on_torch_dispatch_stack(mode_unset)
            torch._C._set_dispatch_mode(old)
            lin = torch.linspace(0.5, h  - 0.5, h)
            # torch._check(lin.shape[0] == sst[i][0])
            reference_points_list.append(lin)
        return reference_points_list

# %%
dynamo.config.verbose=True
# dynamo.config.capture_scalar_outputs = True
# dynamo.config.capture_dynamic_output_shape_ops = True
# torch._dynamo.config.fake_tensor_cache_enabled = False
torch._logging.set_logs(dynamo = logging.DEBUG)

exported_program: torch.export.ExportedProgram = torch.export.export(
    NetC4v6(), (), kwargs=example_kwargs, strict=True,
)
print(exported_program)
# Out:
# V0904 20:34:44.916000 440 torch/_dynamo/convert_frame.py:1216] skipping: _wrapped_call_impl (reason: in skipfiles, file: /Users/dgcnz/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py)
# V0904 20:34:44.916000 440 torch/_dynamo/convert_frame.py:1216] skipping: _call_impl (reason: in skipfiles, file: /Users/dgcnz/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py)
# V0904 20:34:44.922000 440 torch/_dynamo/convert_frame.py:855] [0/0] torchdynamo start compiling forward /var/folders/rk/fqb5s6dn6sl66ntxp1ssybz80000gn/T/ipykernel_440/300679688.py:22, stack (elided 4 frames):
# V0904 20:34:44.922000 440 torch/_dynamo/convert_frame.py:855] [0/0]   File "/Users/dgcnz/.pyenv/versions/3.10.12/lib/python3.10/runpy.py", line 196, in _run_module_as_main
# V0904 20:34:44.922000 440 torch/_dynamo/convert_frame.py:855] [0/0]     return _run_code(code, main_globals, None,
# V0904 20:34:44.922000 440 torch/_dynamo/convert_frame.py:855] [0/0]   File "/Users/dgcnz/.pyenv/versions/3.10.12/lib/python3.10/runpy.py", line 86, in _run_code
# V0904 20:34:44.922000 440 torch/_dynamo/convert_frame.py:855] [0/0]     exec(code, run_globals)
# V0904 20:34:44.922000 440 torch/_dynamo/convert_frame.py:855] [0/0]   File "/Users/dgcnz/development/amsterdam/edge/.venv/lib/python3.10/site-packages/ipykernel_launcher.py", line 18, in <module>
# V0904 20:34:44.922000 440 torch/_dynamo/convert_frame.py:855] [0/0]     app.launch_new_instance()
# V0904 20:34:44.922000 440 torch/_dynamo/convert_frame.py:855] [0/0]   File "/Users/dgcnz/development/amsterdam/edge/.venv/lib/python3.10/site-packages/traitlets/config/application.py", line 1075, in launch_instance
# V0904 20:34:44.922000 440 torch/_dynamo/convert_frame.py:855] [0/0]     app.start()
# V0904 20:34:44.922000 440 torch/_dynamo/convert_frame.py:855] [0/0]   File "/Users/dgcnz/development/amsterdam/edge/.venv/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 739, in start
# V0904 20:34:44.922000 440 torch/_dynamo/convert_frame.py:855] [0/0]     self.io_loop.start()
# V0904 20:34:44.922000 440 torch/_dynamo/convert_frame.py:855] [0/0]   File "/Users/dgcnz/development/amsterdam/edge/.venv/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 205, in start
# V0904 20:34:44.922000 440 torch/_dynamo/convert_frame.py:855] [0/0]     self.asyncio_loop.run_forever()
# V0904 20:34:44.922000 440 torch/_dynamo/convert_frame.py:855] [0/0]   File "/Users/dgcnz/.pyenv/versions/3.10.12/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
# V0904 20:34:44.922000 440 torch/_dynamo/convert_frame.py:855] [0/0]     self._run_once()
# V0904 20:34:44.922000 440 torch/_dynamo/convert_frame.py:855] [0/0]   File "/Users/dgcnz/.pyenv/versions/3.10.12/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
# V0904 20:34:44.922000 440 torch/_dynamo/convert_frame.py:855] [0/0]     handle._run()
# V0904 20:34:44.922000 440 torch/_dynamo/convert_frame.py:855] [0/0]   File "/Users/dgcnz/.pyenv/versions/3.10.12/lib/python3.10/asyncio/events.py", line 80, in _run
# V0904 20:34:44.922000 440 torch/_dynamo/convert_frame.py:855] [0/0]     self._context.run(self._callback, *self._args)
# V0904 20:34:44.922000 440 torch/_dynamo/convert_frame.py:855] [0/0]   File "/Users/dgcnz/development/amsterdam/edge/.venv/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
# V0904 20:34:44.922000 440 torch/_dynamo/convert_frame.py:855] [0/0]     await self.process_one()
# V0904 20:34:44.922000 440 torch/_dynamo/convert_frame.py:855] [0/0]   File "/Users/dgcnz/development/amsterdam/edge/.venv/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 534, in process_one
# V0904 20:34:44.922000 440 torch/_dynamo/convert_frame.py:855] [0/0]     await dispatch(*args)
# V0904 20:34:44.922000 440 torch/_dynamo/convert_frame.py:855] [0/0]   File "/Users/dgcnz/development/amsterdam/edge/.venv/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
# V0904 20:34:44.922000 440 torch/_dynamo/convert_frame.py:855] [0/0]     await result
# V0904 20:34:44.922000 440 torch/_dynamo/convert_frame.py:855] [0/0]   File "/Users/dgcnz/development/amsterdam/edge/.venv/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
# V0904 20:34:44.922000 440 torch/_dynamo/convert_frame.py:855] [0/0]     await super().execute_request(stream, ident, parent)
# V0904 20:34:44.922000 440 torch/_dynamo/convert_frame.py:855] [0/0]   File "/Users/dgcnz/development/amsterdam/edge/.venv/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
# V0904 20:34:44.922000 440 torch/_dynamo/convert_frame.py:855] [0/0]     reply_content = await reply_content
# V0904 20:34:44.922000 440 torch/_dynamo/convert_frame.py:855] [0/0]   File "/Users/dgcnz/development/amsterdam/edge/.venv/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
# V0904 20:34:44.922000 440 torch/_dynamo/convert_frame.py:855] [0/0]     res = shell.run_cell(
# V0904 20:34:44.922000 440 torch/_dynamo/convert_frame.py:855] [0/0]   File "/Users/dgcnz/development/amsterdam/edge/.venv/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
# V0904 20:34:44.922000 440 torch/_dynamo/convert_frame.py:855] [0/0]     return super().run_cell(*args, **kwargs)
# V0904 20:34:44.922000 440 torch/_dynamo/convert_frame.py:855] [0/0]   File "/Users/dgcnz/development/amsterdam/edge/.venv/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3048, in run_cell
# V0904 20:34:44.922000 440 torch/_dynamo/convert_frame.py:855] [0/0]     result = self._run_cell(
# V0904 20:34:44.922000 440 torch/_dynamo/convert_frame.py:855] [0/0]   File "/Users/dgcnz/development/amsterdam/edge/.venv/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3103, in _run_cell
# V0904 20:34:44.922000 440 torch/_dynamo/convert_frame.py:855] [0/0]     result = runner(coro)
# V0904 20:34:44.922000 440 torch/_dynamo/convert_frame.py:855] [0/0]   File "/Users/dgcnz/development/amsterdam/edge/.venv/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
# V0904 20:34:44.922000 440 torch/_dynamo/convert_frame.py:855] [0/0]     coro.send(None)
# V0904 20:34:44.922000 440 torch/_dynamo/convert_frame.py:855] [0/0]   File "/Users/dgcnz/development/amsterdam/edge/.venv/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3308, in run_cell_async
# V0904 20:34:44.922000 440 torch/_dynamo/convert_frame.py:855] [0/0]     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# V0904 20:34:44.922000 440 torch/_dynamo/convert_frame.py:855] [0/0]   File "/Users/dgcnz/development/amsterdam/edge/.venv/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3490, in run_ast_nodes
# V0904 20:34:44.922000 440 torch/_dynamo/convert_frame.py:855] [0/0]     if await self.run_code(code, result, async_=asy):
# V0904 20:34:44.922000 440 torch/_dynamo/convert_frame.py:855] [0/0]   File "/Users/dgcnz/development/amsterdam/edge/.venv/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3550, in run_code
# V0904 20:34:44.922000 440 torch/_dynamo/convert_frame.py:855] [0/0]     exec(code_obj, self.user_global_ns, self.user_ns)
# V0904 20:34:44.922000 440 torch/_dynamo/convert_frame.py:855] [0/0]   File "/var/folders/rk/fqb5s6dn6sl66ntxp1ssybz80000gn/T/ipykernel_440/2188643469.py", line 7, in <module>
# V0904 20:34:44.922000 440 torch/_dynamo/convert_frame.py:855] [0/0]     exported_program: torch.export.ExportedProgram = torch.export.export(
# V0904 20:34:44.922000 440 torch/_dynamo/convert_frame.py:855] [0/0]   File "/Users/dgcnz/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/export/__init__.py", line 258, in export
# V0904 20:34:44.922000 440 torch/_dynamo/convert_frame.py:855] [0/0]     return _export(
# V0904 20:34:44.922000 440 torch/_dynamo/convert_frame.py:855] [0/0]   File "/Users/dgcnz/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/export/_trace.py", line 980, in wrapper
# V0904 20:34:44.922000 440 torch/_dynamo/convert_frame.py:855] [0/0]     ep = fn(*args, **kwargs)
# V0904 20:34:44.922000 440 torch/_dynamo/convert_frame.py:855] [0/0]   File "/Users/dgcnz/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/export/exported_program.py", line 105, in wrapper
# V0904 20:34:44.922000 440 torch/_dynamo/convert_frame.py:855] [0/0]     return fn(*args, **kwargs)
# V0904 20:34:44.922000 440 torch/_dynamo/convert_frame.py:855] [0/0]   File "/Users/dgcnz/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/export/_trace.py", line 1915, in _export
# V0904 20:34:44.922000 440 torch/_dynamo/convert_frame.py:855] [0/0]     export_artifact = export_func(  # type: ignore[operator]
# V0904 20:34:44.922000 440 torch/_dynamo/convert_frame.py:855] [0/0]   File "/Users/dgcnz/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/export/_trace.py", line 1214, in _strict_export
# V0904 20:34:44.922000 440 torch/_dynamo/convert_frame.py:855] [0/0]     return _strict_export_lower_to_aten_ir(
# V0904 20:34:44.922000 440 torch/_dynamo/convert_frame.py:855] [0/0]   File "/Users/dgcnz/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/export/_trace.py", line 1242, in _strict_export_lower_to_aten_ir
# V0904 20:34:44.922000 440 torch/_dynamo/convert_frame.py:855] [0/0]     gm_torch_level = _export_to_torch_ir(
# V0904 20:34:44.922000 440 torch/_dynamo/convert_frame.py:855] [0/0]   File "/Users/dgcnz/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/export/_trace.py", line 550, in _export_to_torch_ir
# V0904 20:34:44.922000 440 torch/_dynamo/convert_frame.py:855] [0/0]     gm_torch_level, _ = torch._dynamo.export(
# V0904 20:34:44.922000 440 torch/_dynamo/convert_frame.py:855] [0/0]   File "/Users/dgcnz/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/_dynamo/eval_frame.py", line 1432, in inner
# V0904 20:34:44.922000 440 torch/_dynamo/convert_frame.py:855] [0/0]     result_traced = opt_f(*args, **kwargs)
# V0904 20:34:44.922000 440 torch/_dynamo/convert_frame.py:855] [0/0]   File "/Users/dgcnz/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1736, in _wrapped_call_impl
# V0904 20:34:44.922000 440 torch/_dynamo/convert_frame.py:855] [0/0]     return self._call_impl(*args, **kwargs)
# V0904 20:34:44.922000 440 torch/_dynamo/convert_frame.py:855] [0/0]   File "/Users/dgcnz/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1747, in _call_impl
# V0904 20:34:44.922000 440 torch/_dynamo/convert_frame.py:855] [0/0]     return forward_call(*args, **kwargs)
# V0904 20:34:44.922000 440 torch/_dynamo/convert_frame.py:855] [0/0]   File "/Users/dgcnz/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/_dynamo/eval_frame.py", line 465, in _fn
# V0904 20:34:44.922000 440 torch/_dynamo/convert_frame.py:855] [0/0]     return fn(*args, **kwargs)
# V0904 20:34:44.922000 440 torch/_dynamo/convert_frame.py:855] [0/0]   File "/Users/dgcnz/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1736, in _wrapped_call_impl
# V0904 20:34:44.922000 440 torch/_dynamo/convert_frame.py:855] [0/0]     return self._call_impl(*args, **kwargs)
# V0904 20:34:44.922000 440 torch/_dynamo/convert_frame.py:855] [0/0]
# I0904 20:34:44.923000 440 torch/_dynamo/utils.py:859] [0/0] ChromiumEventLogger initialized with id b1ee9dab-8230-44a2-8939-9d0565db74ed
# I0904 20:34:44.924000 440 torch/_dynamo/logging.py:57] [0/0] Step 1: torchdynamo start tracing forward /var/folders/rk/fqb5s6dn6sl66ntxp1ssybz80000gn/T/ipykernel_440/300679688.py:22
# V0904 20:34:44.925000 440 torch/fx/experimental/symbolic_shapes.py:2500] [0/0] create_env
# V0904 20:34:44.962000 440 torch/_dynamo/output_graph.py:2076] [0/0] create_graph_input L_x_0_ L['x'][0]
# V0904 20:34:44.963000 440 torch/_dynamo/variables/builder.py:2690] [0/0] wrap_to_fake L['x'][0] (1, 3, 150, 100) StatefulSymbolicContext(dynamic_sizes=[<DimDynamic.DYNAMIC: 0>, <DimDynamic.DYNAMIC: 0>, <DimDynamic.DYNAMIC: 0>, <DimDynamic.DYNAMIC: 0>], dynamic_strides=[<DimDynamic.INFER_STRIDE: 4>, <DimDynamic.INFER_STRIDE: 4>, <DimDynamic.INFER_STRIDE: 4>, <DimDynamic.INFER_STRIDE: 4>], constraint_sizes=[StrictMinMaxConstraint(warn_only=False, vr=VR[1, 1]), StrictMinMaxConstraint(warn_only=False, vr=VR[3, 3]), StrictMinMaxConstraint(warn_only=False, vr=VR[150, 150]), StrictMinMaxConstraint(warn_only=False, vr=VR[100, 100])], constraint_strides=[None, None, None, None], view_base_context=None, tensor_source=GetItemSource(base=LocalSource(local_name='x', cell_or_freevar=False), index=0, index_is_slice=False), shape_env_to_source_to_symbol_cache={}) <class 'torch.Tensor'>
# V0904 20:34:44.965000 440 torch/_dynamo/output_graph.py:2076] [0/0] create_graph_input L_x_1_ L['x'][1]
# V0904 20:34:44.966000 440 torch/_dynamo/variables/builder.py:2690] [0/0] wrap_to_fake L['x'][1] (1, 3, 75, 50) StatefulSymbolicContext(dynamic_sizes=[<DimDynamic.DYNAMIC: 0>, <DimDynamic.DYNAMIC: 0>, <DimDynamic.DYNAMIC: 0>, <DimDynamic.DYNAMIC: 0>], dynamic_strides=[<DimDynamic.INFER_STRIDE: 4>, <DimDynamic.INFER_STRIDE: 4>, <DimDynamic.INFER_STRIDE: 4>, <DimDynamic.INFER_STRIDE: 4>], constraint_sizes=[StrictMinMaxConstraint(warn_only=False, vr=VR[1, 1]), StrictMinMaxConstraint(warn_only=False, vr=VR[3, 3]), StrictMinMaxConstraint(warn_only=False, vr=VR[75, 75]), StrictMinMaxConstraint(warn_only=False, vr=VR[50, 50])], constraint_strides=[None, None, None, None], view_base_context=None, tensor_source=GetItemSource(base=LocalSource(local_name='x', cell_or_freevar=False), index=1, index_is_slice=False), shape_env_to_source_to_symbol_cache={}) <class 'torch.Tensor'>
# V0904 20:34:44.967000 440 torch/_dynamo/output_graph.py:2076] [0/0] create_graph_input L_x_2_ L['x'][2]
# V0904 20:34:44.968000 440 torch/_dynamo/variables/builder.py:2690] [0/0] wrap_to_fake L['x'][2] (1, 3, 37, 25) StatefulSymbolicContext(dynamic_sizes=[<DimDynamic.DYNAMIC: 0>, <DimDynamic.DYNAMIC: 0>, <DimDynamic.DYNAMIC: 0>, <DimDynamic.DYNAMIC: 0>], dynamic_strides=[<DimDynamic.INFER_STRIDE: 4>, <DimDynamic.INFER_STRIDE: 4>, <DimDynamic.INFER_STRIDE: 4>, <DimDynamic.INFER_STRIDE: 4>], constraint_sizes=[StrictMinMaxConstraint(warn_only=False, vr=VR[1, 1]), StrictMinMaxConstraint(warn_only=False, vr=VR[3, 3]), StrictMinMaxConstraint(warn_only=False, vr=VR[37, 37]), StrictMinMaxConstraint(warn_only=False, vr=VR[25, 25])], constraint_strides=[None, None, None, None], view_base_context=None, tensor_source=GetItemSource(base=LocalSource(local_name='x', cell_or_freevar=False), index=2, index_is_slice=False), shape_env_to_source_to_symbol_cache={}) <class 'torch.Tensor'>
# V0904 20:34:44.969000 440 torch/_dynamo/output_graph.py:2076] [0/0] create_graph_input L_x_3_ L['x'][3]
# V0904 20:34:44.969000 440 torch/_dynamo/variables/builder.py:2690] [0/0] wrap_to_fake L['x'][3] (1, 3, 19, 13) StatefulSymbolicContext(dynamic_sizes=[<DimDynamic.DYNAMIC: 0>, <DimDynamic.DYNAMIC: 0>, <DimDynamic.DYNAMIC: 0>, <DimDynamic.DYNAMIC: 0>], dynamic_strides=[<DimDynamic.INFER_STRIDE: 4>, <DimDynamic.INFER_STRIDE: 4>, <DimDynamic.INFER_STRIDE: 4>, <DimDynamic.INFER_STRIDE: 4>], constraint_sizes=[StrictMinMaxConstraint(warn_only=False, vr=VR[1, 1]), StrictMinMaxConstraint(warn_only=False, vr=VR[3, 3]), StrictMinMaxConstraint(warn_only=False, vr=VR[19, 19]), StrictMinMaxConstraint(warn_only=False, vr=VR[13, 13])], constraint_strides=[None, None, None, None], view_base_context=None, tensor_source=GetItemSource(base=LocalSource(local_name='x', cell_or_freevar=False), index=3, index_is_slice=False), shape_env_to_source_to_symbol_cache={}) <class 'torch.Tensor'>
# V0904 20:34:44.970000 440 torch/_dynamo/symbolic_convert.py:865] [0/0] [__trace_source] TRACE starts_line /var/folders/rk/fqb5s6dn6sl66ntxp1ssybz80000gn/T/ipykernel_440/300679688.py:23 in forward
# V0904 20:34:44.970000 440 torch/_dynamo/symbolic_convert.py:865] [0/0] [__trace_source]             ss: typing.List[typing.Tuple[int, int]] =[(150, 100), (75, 50), (37, 25), (19, 13)]
# V0904 20:34:44.971000 440 torch/_dynamo/symbolic_convert.py:888] [0/0] [__trace_bytecode] TRACE BUILD_LIST 0 []
# V0904 20:34:44.971000 440 torch/_dynamo/symbolic_convert.py:888] [0/0] [__trace_bytecode] TRACE LOAD_CONST ((150, 100), (75, 50), (37, 25), (19, 13)) [ListVariable(length=0)]
# V0904 20:34:44.972000 440 torch/_dynamo/symbolic_convert.py:888] [0/0] [__trace_bytecode] TRACE LIST_EXTEND 1 [ListVariable(length=0), TupleVariable(length=4)]
# V0904 20:34:44.972000 440 torch/_dynamo/symbolic_convert.py:888] [0/0] [__trace_bytecode] TRACE STORE_FAST ss [ListVariable(length=4)]
# V0904 20:34:44.972000 440 torch/_dynamo/symbolic_convert.py:865] [0/0] [__trace_source] TRACE starts_line /var/folders/rk/fqb5s6dn6sl66ntxp1ssybz80000gn/T/ipykernel_440/300679688.py:27 in forward
# V0904 20:34:44.972000 440 torch/_dynamo/symbolic_convert.py:865] [0/0] [__trace_source]             old = torch._C._unset_dispatch_mode(torch._C._TorchDispatchModeKey.FAKE)
# V0904 20:34:44.973000 440 torch/_dynamo/symbolic_convert.py:888] [0/0] [__trace_bytecode] TRACE LOAD_GLOBAL torch []
# V0904 20:34:44.974000 440 torch/_dynamo/symbolic_convert.py:888] [0/0] [__trace_bytecode] TRACE LOAD_ATTR _C [PythonModuleVariable(<module 'torch' from '/Users/dgcnz/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/__init__.py'>)]
# V0904 20:34:44.975000 440 torch/_dynamo/symbolic_convert.py:888] [0/0] [__trace_bytecode] TRACE LOAD_ATTR _unset_dispatch_mode [PythonModuleVariable(<module 'torch._C' from '/Users/dgcnz/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/_C.cpython-310-darwin.so'>)]
# V0904 20:34:44.976000 440 torch/_dynamo/symbolic_convert.py:888] [0/0] [__trace_bytecode] TRACE LOAD_GLOBAL torch [TorchInGraphFunctionVariable(<built-in function _unset_dispatch_mode>)]
# V0904 20:34:44.976000 440 torch/_dynamo/symbolic_convert.py:888] [0/0] [__trace_bytecode] TRACE LOAD_ATTR _C [TorchInGraphFunctionVariable(<built-in function _unset_dispatch_mode>), PythonModuleVariable(<module 'torch' from '/Users/dgcnz/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/__init__.py'>)]
# V0904 20:34:44.977000 440 torch/_dynamo/symbolic_convert.py:888] [0/0] [__trace_bytecode] TRACE LOAD_ATTR _TorchDispatchModeKey [TorchInGraphFunctionVariable(<built-in function _unset_dispatch_mode>), PythonModuleVariable(<module 'torch._C' from '/Users/dgcnz/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/_C.cpython-310-darwin.so'>)]
# V0904 20:34:44.977000 440 torch/_dynamo/symbolic_convert.py:888] [0/0] [__trace_bytecode] TRACE LOAD_ATTR FAKE [TorchInGraphFunctionVariable(<built-in function _unset_dispatch_mode>), UserDefinedClassVariable()]
# V0904 20:34:44.978000 440 torch/_dynamo/symbolic_convert.py:888] [0/0] [__trace_bytecode] TRACE CALL_FUNCTION 1 [TorchInGraphFunctionVariable(<built-in function _unset_dispatch_mode>), UserDefinedObjectVariable(_TorchDispatchModeKey)]
# V0904 20:34:44.979000 440 torch/_dynamo/symbolic_convert.py:904] [0/0] empty checkpoint
# -1 0
# -1 0
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File ~/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/_dynamo/utils.py:737, in proxy_args_kwargs(args, kwargs)
#     736 try:
# --> 737     proxy_args = tuple(arg.as_proxy() for arg in args)
#     738     proxy_kwargs = {key: arg.as_proxy() for key, arg in kwargs.items()}
#
# File ~/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/_dynamo/utils.py:737, in <genexpr>(.0)
#     736 try:
# --> 737     proxy_args = tuple(arg.as_proxy() for arg in args)
#     738     proxy_kwargs = {key: arg.as_proxy() for key, arg in kwargs.items()}
#
# File ~/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/_dynamo/variables/base.py:257, in VariableTracker.as_proxy(self)
#     256 def as_proxy(self):
# --> 257     raise NotImplementedError(str(self))
#
# NotImplementedError: UserDefinedObjectVariable(_TorchDispatchModeKey)
#
# The above exception was the direct cause of the following exception:
#
# Unsupported                               Traceback (most recent call last)
# Cell In[14], line 7
#       2 # dynamo.config.capture_scalar_outputs = True
#       3 # dynamo.config.capture_dynamic_output_shape_ops = True
#       4 # torch._dynamo.config.fake_tensor_cache_enabled = False
#       5 torch._logging.set_logs(dynamo = logging.DEBUG)
# ----> 7 exported_program: torch.export.ExportedProgram = torch.export.export(
#       8     NetC4v6(), (), kwargs=example_kwargs, strict=True,
#       9 )
#      10 print(exported_program)
#
# File ~/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/export/__init__.py:258, in export(mod, args, kwargs, dynamic_shapes, strict, preserve_module_call_signature)
#     254 if not isinstance(mod, torch.nn.Module):
#     255     raise ValueError(
#     256         f"Expected `mod` to be an instance of `torch.nn.Module`, got {type(mod)}."
#     257     )
# --> 258 return _export(
#     259     mod,
#     260     args,
#     261     kwargs,
#     262     dynamic_shapes,
#     263     strict=strict,
#     264     preserve_module_call_signature=preserve_module_call_signature,
#     265     pre_dispatch=True,
#     266 )
#
# File ~/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/export/_trace.py:1007, in _log_export_wrapper.<locals>.wrapper(*args, **kwargs)
#    1000     else:
#    1001         log_export_usage(
#    1002             event="export.error.unclassified",
#    1003             type=error_type,
#    1004             message=str(e),
#    1005             flags=_EXPORT_FLAGS,
#    1006         )
# -> 1007     raise e
#    1008 finally:
#    1009     _EXPORT_FLAGS = None
#
# File ~/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/export/_trace.py:980, in _log_export_wrapper.<locals>.wrapper(*args, **kwargs)
#     978 try:
#     979     start = time.time()
# --> 980     ep = fn(*args, **kwargs)
#     981     end = time.time()
#     982     log_export_usage(
#     983         event="export.time",
#     984         metrics=end - start,
#     985         flags=_EXPORT_FLAGS,
#     986         **get_ep_stats(ep),
#     987     )
#
# File ~/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/export/exported_program.py:105, in _disable_prexisiting_fake_mode.<locals>.wrapper(*args, **kwargs)
#     102 @functools.wraps(fn)
#     103 def wrapper(*args, **kwargs):
#     104     with unset_fake_temporarily():
# --> 105         return fn(*args, **kwargs)
#
# File ~/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/export/_trace.py:1915, in _export(mod, args, kwargs, dynamic_shapes, strict, preserve_module_call_signature, pre_dispatch, allow_complex_guards_as_runtime_asserts, _is_torch_jit_trace)
#    1912 # Call the appropriate export function based on the strictness of tracing.
#    1913 export_func = _strict_export if strict else _non_strict_export
# -> 1915 export_artifact = export_func(  # type: ignore[operator]
#    1916     mod,
#    1917     args,
#    1918     kwargs,
#    1919     dynamic_shapes,
#    1920     preserve_module_call_signature,
#    1921     pre_dispatch,
#    1922     original_state_dict,
#    1923     original_in_spec,
#    1924     allow_complex_guards_as_runtime_asserts,
#    1925     _is_torch_jit_trace,
#    1926 )
#    1927 export_graph_signature: ExportGraphSignature = export_artifact.aten.sig
#    1929 forward_arg_names = (
#    1930     _get_forward_arg_names(mod, args, kwargs) if not _is_torch_jit_trace else None
#    1931 )
#
# File ~/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/export/_trace.py:1214, in _strict_export(mod, args, kwargs, dynamic_shapes, preserve_module_call_signature, pre_dispatch, original_state_dict, orig_in_spec, allow_complex_guards_as_runtime_asserts, _is_torch_jit_trace)
#    1201 def _strict_export(
#    1202     mod: torch.nn.Module,
#    1203     args: Tuple[Any, ...],
#    (...)
#    1211     _is_torch_jit_trace: bool,
#    1212 ) -> ExportArtifact:
#    1213     lower_to_aten = functools.partial(_export_to_aten_ir, pre_dispatch=pre_dispatch)
# -> 1214     return _strict_export_lower_to_aten_ir(
#    1215         mod=mod,
#    1216         args=args,
#    1217         kwargs=kwargs,
#    1218         dynamic_shapes=dynamic_shapes,
#    1219         preserve_module_call_signature=preserve_module_call_signature,
#    1220         pre_dispatch=pre_dispatch,
#    1221         original_state_dict=original_state_dict,
#    1222         orig_in_spec=orig_in_spec,
#    1223         allow_complex_guards_as_runtime_asserts=allow_complex_guards_as_runtime_asserts,
#    1224         _is_torch_jit_trace=_is_torch_jit_trace,
#    1225         lower_to_aten_callback=lower_to_aten,
#    1226     )
#
# File ~/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/export/_trace.py:1242, in _strict_export_lower_to_aten_ir(mod, args, kwargs, dynamic_shapes, preserve_module_call_signature, pre_dispatch, original_state_dict, orig_in_spec, allow_complex_guards_as_runtime_asserts, _is_torch_jit_trace, lower_to_aten_callback)
#    1229 def _strict_export_lower_to_aten_ir(
#    1230     mod: torch.nn.Module,
#    1231     args: Tuple[Any, ...],
#    (...)
#    1240     lower_to_aten_callback: Callable,
#    1241 ) -> ExportArtifact:
# -> 1242     gm_torch_level = _export_to_torch_ir(
#    1243         mod,
#    1244         args,
#    1245         kwargs,
#    1246         dynamic_shapes,
#    1247         preserve_module_call_signature=preserve_module_call_signature,
#    1248         restore_fqn=False,  # don't need to restore because we will do it later
#    1249         allow_complex_guards_as_runtime_asserts=allow_complex_guards_as_runtime_asserts,
#    1250         _log_export_usage=False,
#    1251     )
#    1253     # We detect the fake_mode by looking at gm_torch_level's placeholders, this is the fake_mode created in dynamo.
#    1254     (
#    1255         fake_args,
#    1256         fake_kwargs,
#    1257         dynamo_fake_mode,
#    1258     ) = _extract_fake_inputs(gm_torch_level, args, kwargs)
#
# File ~/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/export/_trace.py:550, in _export_to_torch_ir(f, args, kwargs, dynamic_shapes, preserve_module_call_signature, disable_constraint_solver, allow_complex_guards_as_runtime_asserts, restore_fqn, _log_export_usage, same_signature)
#     546     module_call_specs: Dict[str, Dict[str, pytree.TreeSpec]] = {}
#     547     with _wrap_submodules(
#     548         f, preserve_module_call_signature, module_call_specs
#     549     ), _ignore_backend_decomps():
# --> 550         gm_torch_level, _ = torch._dynamo.export(
#     551             f,
#     552             dynamic_shapes=_dynamic_shapes,  # type: ignore[arg-type]
#     553             tracing_mode="symbolic",
#     554             disable_constraint_solver=disable_constraint_solver,
#     555             # currently the following 2 flags are tied together for export purposes,
#     556             # but untangle for sake of dynamo export api
#     557             prefer_deferred_runtime_asserts_over_guards=True,
#     558             allow_complex_guards_as_runtime_asserts=allow_complex_guards_as_runtime_asserts,
#     559             _log_export_usage=_log_export_usage,
#     560             same_signature=same_signature,
#     561         )(
#     562             *args,
#     563             **kwargs,
#     564         )
#     565 except (ConstraintViolationError, ValueRangeError) as e:
#     566     raise UserError(UserErrorType.CONSTRAINT_VIOLATION, str(e))  # noqa: B904
#
# File ~/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/_dynamo/eval_frame.py:1432, in export.<locals>.inner(*args, **kwargs)
#    1430 # TODO(voz): We may have instances of `f` that mutate inputs, we should track sideeffects and reject.
#    1431 try:
# -> 1432     result_traced = opt_f(*args, **kwargs)
#    1433 except ConstraintViolationError as e:
#    1434     constraint_violation_error = e
#
# File ~/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/_dynamo/eval_frame.py:465, in _TorchDynamoContext.__call__.<locals>._fn(*args, **kwargs)
#     460 saved_dynamic_layer_stack_depth = (
#     461     torch._C._functorch.get_dynamic_layer_stack_depth()
#     462 )
#     464 try:
# --> 465     return fn(*args, **kwargs)
#     466 finally:
#     467     # Restore the dynamic layer stack depth if necessary.
#     468     torch._C._functorch.pop_dynamic_layer_stack_and_undo_to_depth(
#     469         saved_dynamic_layer_stack_depth
#     470     )
#
# File ~/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/_dynamo/convert_frame.py:1251, in CatchErrorsWrapper.__call__(self, frame, cache_entry, frame_state)
#    1245             return hijacked_callback(
#    1246                 frame, cache_entry, self.hooks, frame_state
#    1247             )
#    1249 with compile_lock, _disable_current_modes():
#    1250     # skip=1: skip this frame
# -> 1251     return self._torchdynamo_orig_callable(
#    1252         frame, cache_entry, self.hooks, frame_state, skip=1
#    1253     )
#
# File ~/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/_dynamo/convert_frame.py:523, in ConvertFrameAssert.__call__(self, frame, cache_entry, hooks, frame_state, skip)
#     507 compile_id = CompileId(frame_id, frame_compile_id)
#     509 signpost_event(
#     510     "dynamo",
#     511     "_convert_frame_assert._compile",
#    (...)
#     520     },
#     521 )
# --> 523 return _compile(
#     524     frame.f_code,
#     525     frame.f_globals,
#     526     frame.f_locals,
#     527     frame.f_builtins,
#     528     self._torchdynamo_orig_callable,
#     529     self._one_graph,
#     530     self._export,
#     531     self._export_constraints,
#     532     hooks,
#     533     cache_entry,
#     534     cache_size,
#     535     frame,
#     536     frame_state=frame_state,
#     537     compile_id=compile_id,
#     538     skip=skip + 1,
#     539 )
#
# File ~/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/_dynamo/convert_frame.py:915, in _compile(code, globals, locals, builtins, compiler_fn, one_graph, export, export_constraints, hooks, cache_entry, cache_size, frame, frame_state, compile_id, skip)
#     913 guarded_code = None
#     914 try:
# --> 915     guarded_code = compile_inner(code, one_graph, hooks, transform)
#     916     return guarded_code
#     917 except (
#     918     Unsupported,
#     919     TorchRuntimeError,
#    (...)
#     926     BisectValidationException,
#     927 ) as e:
#
# File ~/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/_dynamo/convert_frame.py:663, in _compile.<locals>.compile_inner(code, one_graph, hooks, transform)
#     661 with dynamo_timed("_compile.compile_inner", phase_name="entire_frame_compile"):
#     662     with CompileTimeInstructionCounter.record():
# --> 663         return _compile_inner(code, one_graph, hooks, transform)
#
# File ~/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/_utils_internal.py:87, in compile_time_strobelight_meta.<locals>.compile_time_strobelight_meta_inner.<locals>.wrapper_function(*args, **kwargs)
#      84     kwargs["skip"] = kwargs["skip"] + 1
#      86 if not StrobelightCompileTimeProfiler.enabled:
# ---> 87     return function(*args, **kwargs)
#      89 return StrobelightCompileTimeProfiler.profile_compile_time(
#      90     function, phase_name, *args, **kwargs
#      91 )
#
# File ~/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/_dynamo/convert_frame.py:696, in _compile.<locals>._compile_inner(code, one_graph, hooks, transform)
#     694 CompileContext.get().attempt = attempt
#     695 try:
# --> 696     out_code = transform_code_object(code, transform)
#     697     break
#     698 except exc.RestartAnalysis as e:
#
# File ~/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/_dynamo/bytecode_transformation.py:1322, in transform_code_object(code, transformations, safe)
#    1319 instructions = cleaned_instructions(code, safe)
#    1320 propagate_line_nums(instructions)
# -> 1322 transformations(instructions, code_options)
#    1323 return clean_and_assemble_instructions(instructions, keys, code_options)[1]
#
# File ~/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/_dynamo/convert_frame.py:216, in preserve_global_state.<locals>._fn(*args, **kwargs)
#     212 exit_stack.enter_context(
#     213     torch.fx._symbolic_trace._maybe_revert_all_patches()
#     214 )
#     215 try:
# --> 216     return fn(*args, **kwargs)
#     217 finally:
#     218     cleanup.close()
#
# File ~/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/_dynamo/convert_frame.py:631, in _compile.<locals>.transform(instructions, code_options)
#     629 try:
#     630     with tracing(tracer.output.tracing_context), tracer.set_current_tx():
# --> 631         tracer.run()
#     632 except exc.UnspecializeRestartAnalysis:
#     633     speculation_log.clear()
#
# File ~/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/_dynamo/symbolic_convert.py:2796, in InstructionTranslator.run(self)
#    2795 def run(self):
# -> 2796     super().run()
#
# File ~/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/_dynamo/symbolic_convert.py:983, in InstructionTranslatorBase.run(self)
#     981 try:
#     982     self.output.push_tx(self)
# --> 983     while self.step():
#     984         pass
#     985 except BackendCompilerFailed:
#
# File ~/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/_dynamo/symbolic_convert.py:895, in InstructionTranslatorBase.step(self)
#     892 self.update_block_stack(inst)
#     894 try:
# --> 895     self.dispatch_table[inst.opcode](self, inst)
#     896     return not self.output.should_exit
#     897 except exc.ObservedException as e:
#
# File ~/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/_dynamo/symbolic_convert.py:582, in break_graph_if_unsupported.<locals>.decorator.<locals>.wrapper(self, inst)
#     580     return handle_graph_break(self, inst, speculation.reason)
#     581 try:
# --> 582     return inner_fn(self, inst)
#     583 except Unsupported as excp:
#     584     if self.generic_context_manager_depth > 0:
#     585         # We don't support graph break under GenericContextWrappingVariable,
#     586         # If there is, we roll back to the checkpoint and fall back.
#
# File ~/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/_dynamo/symbolic_convert.py:1602, in InstructionTranslatorBase.CALL_FUNCTION(self, inst)
#    1600 args = self.popn(inst.argval)
#    1601 fn = self.pop()
# -> 1602 self.call_function(fn, args, {})
#
# File ~/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/_dynamo/symbolic_convert.py:830, in InstructionTranslatorBase.call_function(self, fn, args, kwargs)
#     828 if inner_fn and callable(inner_fn) and is_forbidden(inner_fn):
#     829     raise AssertionError(f"Attempt to trace forbidden callable {inner_fn}")
# --> 830 self.push(fn.call_function(self, args, kwargs))
#
# File ~/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/_dynamo/variables/torch.py:892, in TorchInGraphFunctionVariable.call_function(self, tx, args, kwargs)
#     878             if "out" in kwargs and isinstance(kwargs["out"], variables.TensorVariable):
#     879                 # Calling fake tensor propagation can mutate the out= tensor in
#     880                 # tx.output.tracked_fakes. tracked_fakes are used to apply
#    (...)
#     883                 # guards. So save the shape now, and check later if it has
#     884                 # changed. If it has, graph break.
#     885                 fake_out_shape = kwargs["out"].proxy.node.meta["example_value"].shape
#     887             tensor_variable = wrap_fx_proxy(
#     888                 tx=tx,
#     889                 proxy=tx.output.create_proxy(
#     890                     "call_function",
#     891                     fn_,
# --> 892                     *proxy_args_kwargs(args, kwargs),
#     893                 ),
#     894             )
#     896             if (
#     897                 isinstance(tensor_variable, TensorVariable)
#     898                 and "requires_grad" in kwargs
#     899                 and kwargs["requires_grad"].as_python_constant()
#     900             ):
#     901                 unimplemented(
#     902                     """factory functions that return tensors that require grad are not supported.
#     903 Either create the tensor outside the compiled region, or do not set the tensor to require_grad"""
#     904                 )
#
# File ~/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/_dynamo/utils.py:744, in proxy_args_kwargs(args, kwargs)
#     741 from .exc import unimplemented
#     742 from .variables.base import typestr
# --> 744 unimplemented(
#     745     f"call_function args: {typestr(*args)} {typestr(*list(kwargs.values()))}",
#     746     from_exc=e,
#     747 )
#
# File ~/development/amsterdam/edge/.venv/lib/python3.10/site-packages/torch/_dynamo/exc.py:288, in unimplemented(msg, from_exc, case_name)
#     286 assert msg != os.environ.get("BREAK", False)
#     287 if from_exc is not _NOTHING:
# --> 288     raise Unsupported(msg, case_name=case_name) from from_exc
#     289 raise Unsupported(msg, case_name=case_name)
#
# Unsupported: call_function args: UserDefinedObjectVariable(_TorchDispatchModeKey)
#
# from user code:
#    File "/var/folders/rk/fqb5s6dn6sl66ntxp1ssybz80000gn/T/ipykernel_440/300679688.py", line 27, in forward
#     old = torch._C._unset_dispatch_mode(torch._C._TorchDispatchModeKey.FAKE)

# %% [markdown]
# Seems to work for strict=False only, that's a shame. Also it requires non-trivial rewrites that I probably should avoid anyway.
